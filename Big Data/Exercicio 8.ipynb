# %%
# Algumas bibliotecas necessárias 
#!pip install psycopg[binary]

# %%
# !docker pull apache/age
# Out:
# Using default tag: latest
# latest: Pulling from apache/age
# Digest: sha256:9c88caf778914db658f7da8e54ba94c767aed03270b7bce9f7880efd42bd13fd
# Status: Image is up to date for apache/age:latest
# docker.io/apache/age:latest

# %% [markdown]
# ## 1. Subindo o container

# %%
# !docker compose down
# !docker compose up -d --force-recreate
# Out:
#  Container postgres-age  Stopping
#  Container postgres-age  Stopped
#  Container postgres-age  Removing
#  Container postgres-age  Removed
#  Network atividade9_default  Removing
#  Network atividade9_default  Removed
#  Network atividade9_default  Creating
#  Network atividade9_default  Created
#  Container postgres-age  Creating
#  Container postgres-age  Created
#  Container postgres-age  Starting
#  Container postgres-age  Started

# %%
# Verifica se container foi criado
# !docker ps
# Out:
# CONTAINER ID   IMAGE               COMMAND                  CREATED         STATUS         PORTS                    NAMES
# a59afd4a9c63   apache/age:latest   "docker-entrypoint.s…"   4 seconds ago   Up 3 seconds   0.0.0.0:5433->5432/tcp   postgres-age

# %% [markdown]
# # 2. Conectando ao banco

# %%
import psycopg

conn = psycopg.connect(
    host="localhost",
    port=5433,
    user="postgres",
    password="postgres",
    dbname="openflights"
)

cur = conn.cursor()
cur.execute("SELECT version();")
print(cur.fetchone())
# Out:
# ('PostgreSQL 16.10 (Debian 16.10-1.pgdg13+1) on x86_64-pc-linux-gnu, compiled by gcc (Debian 14.2.0-19) 14.2.0, 64-bit',)

# %% [markdown]
# # 3. Criando as tabelas SQL

# %%
# Tabela airports
create_command_airports = """
    DROP TABLE IF EXISTS airports;

    CREATE TABLE airports(
        airport_id            INTEGER,            -- ID único
        name                  TEXT,               -- Nome do aeroporto
        city                  TEXT,               -- Cidade
        country               TEXT,               -- País
        iata                  TEXT,               -- Código IATA
        icao                  TEXT,               -- Código ICAO
        latitude              DOUBLE PRECISION,   -- Lat
        longitude             DOUBLE PRECISION,   -- Long
        height                INTEGER,            -- Altitude em pés
        timezone              DOUBLE PRECISION,   -- Offset UTC
        dst                   TEXT,               -- Tipo DST
        tz_database_timezone  TEXT,               -- Timezone Olson
        type                  TEXT,               -- airport/station/etc
        source                TEXT                -- Origem do dado
    );
"""

copy_command_airports = """
COPY airports
FROM '/data/airports.csv'
WITH (FORMAT csv, HEADER false, NULL '\\N');
"""

conn.rollback()
cur.execute(create_command_airports)
cur.execute(copy_command_airports)
conn.commit()

# %%
# Tabela routes
create_command_routes = """
    DROP TABLE IF EXISTS routes;

    CREATE TABLE IF NOT EXISTS routes (
        company                 TEXT,    -- Código da companhia (IATA/ICAO)
        airline_id              INTEGER, -- ID da companhia no OpenFlights
        source_airport          TEXT,    -- Aeroporto de origem (IATA/ICAO)
        source_airport_id       INTEGER, -- ID OpenFlights do aeroporto de origem
        destination_airport     TEXT,    -- Aeroporto de destino (IATA/ICAO)
        destination_airport_id  INTEGER, -- ID OpenFlights do aeroporto de destino
        codeshare               TEXT,    -- 'Y' para codeshare
        stops                   INTEGER, -- Número de escalas
        equipment               TEXT     -- Tipos de aviões, separados por espaço
    );
"""

copy_command_routes = """
COPY routes
FROM '/data/routes.csv'
WITH (FORMAT csv, HEADER false, NULL '\\N');
"""

conn.rollback()
cur.execute(create_command_routes)
cur.execute(copy_command_routes)
conn.commit()

# %%
conn.rollback()

# Remover extensão AGE e recriar
cur.execute("DROP EXTENSION IF EXISTS age CASCADE;")
cur.execute("CREATE EXTENSION age;")
cur.execute("LOAD 'age';")
cur.execute("SET search_path = ag_catalog, \"$user\", public;")
conn.commit()

print("Extensão AGE recriada.")
# Out:
# Extensão AGE recriada.

# %%
# Remover grafo se existir e criar novamente
conn.rollback()
cur.execute("""
DO $$
BEGIN
    IF EXISTS (
        SELECT 1 FROM ag_catalog.ag_graph WHERE name = 'openflights_graph'
    ) THEN
        PERFORM drop_graph('openflights_graph', true);
    END IF;
END$$;
""")

cur.execute("SELECT create_graph('openflights_graph');")
conn.commit()

print("Grafo openflights_graph criado.")
# Out:
# Grafo openflights_graph criado.

# %%
conn.rollback()
cur.execute("""
    SET search_path = "$user", public, ag_catalog;
""")
conn.commit()

print("search_path corrigido.")
# Out:
# search_path corrigido.

# %%
# Funções utilitárias
import json
from math import ceil

def cy_escape(s):
    """
    Tratamento de strings para Cypher
    Subsitui ' por \', e garante None-> null literal
    """
    if s is None:
        return 'null'

    s = str(s)
    s = s.replace("\\","\\\\").replace("'", "\\'")
    return f"'{s}'"

import json

def chunked(seq, size):
    for i in range(0, len(seq), size):
        yield seq[i:i+size]

def run_cypher(cypher_text, params=None):
    if params is None:
        q = f"""
            SELECT * FROM cypher(
                'openflights_graph',
                $${cypher_text}$$
            ) AS (result agtype);
        """
        cur.execute(q)
    else:
        q = f"""
            SELECT * FROM cypher(
                'openflights_graph',
                $${cypher_text}$$,
                # %s
            ) AS (result agtype);
        """
        cur.execute(q, (json.dumps(params),))

    try:
        return cur.fetchall()
    except psycopg.errors.InFailedSqlTransaction:
        conn.rollback()
        raise

# %% [markdown]
# # 4. Criando o grafo

# %%
conn.rollback()

# Buscar aeroportos da tabela staging
cur.execute("""
    SELECT airport_id, name, city, country, iata, icao,
           latitude, longitude, height, timezone, dst,
           tz_database_timezone, type, source
    FROM airports;
""")
rows = cur.fetchall()

print("Total airports:", len(rows))

batch_size = 1000

for batch in chunked(rows, batch_size):
    param_rows = []
    for r in batch:
        param_rows.append({
            "airport_id": r[0],
            "name": r[1],
            "city": r[2],
            "country": r[3],
            "iata": r[4],
            "icao": r[5],
            "latitude": r[6],
            "longitude": r[7],
            "height": r[8],
            "timezone": r[9],
            "dst": r[10],
            "tz_database_timezone": r[11],
            "type": r[12],
            "source": r[13]
        })

    cypher = """
        UNWIND $rows AS r
        CREATE (a:Airport)
        SET a = r
        RETURN count(a)
    """

    out = run_cypher(cypher, params={"rows": param_rows})

conn.commit()
print("Inserção de Airports concluída.")
# Out:
# Total airports: 7698
# Inserção de Airports concluída.

# %%
# Cria tabela de mapeamento de ids do aeroporto e nó
# Torna a criação das arestas mais eficiente
conn.rollback()

cur.execute("""
    DROP TABLE IF EXISTS airport_node_map;

    CREATE TABLE airport_node_map (
        airport_id INTEGER PRIMARY KEY,
        node_id BIGINT
    );
""")

conn.commit()
print("Tabela airport_node_map criada.")
# Out:
# Tabela airport_node_map criada.

# %%
# Populando a tabela de node map
conn.rollback()
rows = []

# Selecionas os vértices
cur.execute("""
    SELECT airport_id, node_id FROM cypher(
        'openflights_graph',
        $$ MATCH (a:Airport) RETURN a.airport_id AS airport_id, id(a) AS node_id $$
    ) AS (airport_id agtype, node_id agtype);
""")

rows = cur.fetchall()

print("Total nodes:", len(rows))

import json

# Converte o json para tuplas
parsed_rows = []
for airport_id_raw, node_id_raw in rows:
    airport_id = json.loads(str(airport_id_raw))
    node_id = json.loads(str(node_id_raw))
    parsed_rows.append((airport_id, node_id))

# Insere os ids (aeroporto, nó)
cur.executemany(
    "INSERT INTO airport_node_map (airport_id, node_id) VALUES (%s, %s)",
    parsed_rows
)
conn.commit()

print("Tabela airport_node_map populada.")
# Out:
# Total nodes: 7698
# Tabela airport_node_map populada.

# %%
# Join nos ids dos nós e nos ids dos aeroportos
conn.rollback()
cur.execute("""
    SELECT r.company, r.airline_id,
           src.node_id AS src_node,
           dst.node_id AS dst_node,
           r.codeshare, r.stops, r.equipment
    FROM routes r
    JOIN airport_node_map src ON src.airport_id = r.source_airport_id
    JOIN airport_node_map dst ON dst.airport_id = r.destination_airport_id;
""")

route_rows = cur.fetchall()
print("Total rotas com nodes:", len(route_rows))
# Out:
# Total rotas com nodes: 66771

# %%
batch_size = 2000

for batch in chunked(route_rows, batch_size):
    param_rows = []
    for r in batch:
        param_rows.append({
            "company": r[0],
            "airline_id": r[1],
            "src": r[2],
            "dst": r[3],
            "codeshare": r[4],
            "stops": r[5],
            "equipment": r[6]
        })

    cypher = """
        UNWIND $rows AS r
        MATCH (src) WHERE id(src) = r.src
        MATCH (dst) WHERE id(dst) = r.dst
        CREATE (src)-[e:ROUTE]->(dst)
        SET e = {
            company: r.company,
            airline_id: r.airline_id,
            codeshare: r.codeshare,
            stops: r.stops,
            equipment: r.equipment
        }
        RETURN count(e)
    """

    out = run_cypher(cypher, params={"rows": param_rows})

conn.commit()
print("Inserção de rotas concluída!")
# Out:
# Inserção de rotas concluída!

# %%
conn.rollback()
cur.execute("""
    SELECT origem, destino FROM cypher(
        'openflights_graph',
        $$
            MATCH (br:Airport {country:'Brazil'})-[r:ROUTE]->(dest)
            RETURN br.name AS origem, dest.name AS destino
            LIMIT 20
        $$
    ) AS (origem text, destino text);
""")

rows = cur.fetchall()
print(rows)
# Out:
# [('Pampulha - Carlos Drummond de Andrade Airport', 'Leite Lopes Airport'), ('Presidente Juscelino Kubistschek International Airport', 'Leite Lopes Airport'), ('Presidente Juscelino Kubistschek International Airport', 'Presidente João Batista Figueiredo Airport'), ('Presidente Juscelino Kubistschek International Airport', 'Barreiras Airport'), ('Cascavel Airport', 'Guarulhos - Governador André Franco Montoro International Airport'), ('Campo Grande Airport', 'Dourados Airport'), ('Afonso Pena Airport', 'Carrasco International /General C L Berisso Airport'), ('Marechal Rondon Airport', 'Presidente João Batista Figueiredo Airport'), ('Marechal Rondon Airport', 'Santa Genoveva Airport'), ('Rio Galeão – Tom Jobim International Airport', 'Leite Lopes Airport'), ('Rio Galeão – Tom Jobim International Airport', 'Carrasco International /General C L Berisso Airport'), ('Santa Genoveva Airport', 'Ten. Cel. Aviador César Bombonato Airport'), ('Santa Genoveva Airport', 'Leite Lopes Airport'), ('Santa Genoveva Airport', 'Brigadeiro Lysias Rodrigues Airport'), ('Santa Genoveva Airport', 'Marechal Rondon Airport'), ('Guarulhos - Governador André Franco Montoro International Airport', 'Vitória da Conquista Airport'), ('Guarulhos - Governador André Franco Montoro International Airport', 'Ten. Cel. Aviador César Bombonato Airport'), ('Guarulhos - Governador André Franco Montoro International Airport', 'Mário de Almeida Franco Airport'), ('Guarulhos - Governador André Franco Montoro International Airport', 'Leite Lopes Airport'), ('Guarulhos - Governador André Franco Montoro International Airport', 'Dourados Airport')]

# %%
import json
import re

# Converte o agtype em dict Python.
# Remove anotações como ::vertex, ::edge, ::path, etc.
def parse_agtype(value: str):
    
    # remove sufixos ::algo
    cleaned = re.sub(r'::[a-zA-Z_]+', '', value)

    return json.loads(cleaned)

# %%
# Query do exercício
conn.rollback()
# Aeroportos de São Paulo (GRU, CGH, VCP)
src_iata = ["GRU", "CGH", "VCP"]
dst_iata = "BSB"  # Brasília

cypher_query = f"""
    SELECT * FROM cypher(
        'openflights_graph',
        $$
        MATCH (src:Airport)
        WHERE src.iata IN {json.dumps(src_iata)}

        MATCH (dst:Airport {{iata: "{dst_iata}"}})

        MATCH p = (src)-[:ROUTE*1..3]->(dst)
        RETURN {{
            airports: nodes(p),
            legs: relationships(p),
            hops: length(p)
        }} AS result
        ORDER BY length(p)
        LIMIT 50
        $$
    ) AS (result agtype);
"""

cur.execute(cypher_query)
rows = cur.fetchall()

# %%
print("Rotas:")
for r in rows:
    raw = r[0]
    parsed = parse_agtype(raw)
    print(json.dumps(parsed, indent=4))
# Out:
# Rotas:
# {
#     "hops": 1,
#     "legs": [
#         {
#             "id": 1125899906871295,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134455,
#             "properties": {
#                 "stops": 0,
#                 "company": "G3",
#                 "codeshare": "",
#                 "equipment": "738 73G",
#                 "airline_id": 1790
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134455,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "CGH",
#                 "icao": "SBSP",
#                 "name": "Congonhas Airport",
#                 "type": "airport",
#                 "height": 2631,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.626110076904297,
#                 "timezone": -3.0,
#                 "longitude": -46.65638732910156,
#                 "airport_id": 2618,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 1,
#     "legs": [
#         {
#             "id": 1125899906885641,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134405,
#             "properties": {
#                 "stops": 0,
#                 "company": "O6",
#                 "codeshare": "",
#                 "equipment": "320 318",
#                 "airline_id": 3764
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134405,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "GRU",
#                 "icao": "SBGR",
#                 "name": "Guarulhos - Governador Andr\u00e9 Franco Montoro International Airport",
#                 "type": "airport",
#                 "height": 2459,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.435556411743164,
#                 "timezone": -3.0,
#                 "longitude": -46.47305679321289,
#                 "airport_id": 2564,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 1,
#     "legs": [
#         {
#             "id": 1125899906871215,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134419,
#             "properties": {
#                 "stops": 0,
#                 "company": "G3",
#                 "codeshare": "",
#                 "equipment": "738 73G",
#                 "airline_id": 1790
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134419,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Campinas",
#                 "iata": "VCP",
#                 "icao": "SBKP",
#                 "name": "Viracopos International Airport",
#                 "type": "airport",
#                 "height": 2170,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.0074005127,
#                 "timezone": -3.0,
#                 "longitude": -47.1344985962,
#                 "airport_id": 2578,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 1,
#     "legs": [
#         {
#             "id": 1125899906875755,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134419,
#             "properties": {
#                 "stops": 0,
#                 "company": "JJ",
#                 "codeshare": "",
#                 "equipment": "320",
#                 "airline_id": 4867
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134419,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Campinas",
#                 "iata": "VCP",
#                 "icao": "SBKP",
#                 "name": "Viracopos International Airport",
#                 "type": "airport",
#                 "height": 2170,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.0074005127,
#                 "timezone": -3.0,
#                 "longitude": -47.1344985962,
#                 "airport_id": 2578,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 1,
#     "legs": [
#         {
#             "id": 1125899906851910,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134405,
#             "properties": {
#                 "stops": 0,
#                 "company": "AD",
#                 "codeshare": "",
#                 "equipment": "E95",
#                 "airline_id": 13983
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134405,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "GRU",
#                 "icao": "SBGR",
#                 "name": "Guarulhos - Governador Andr\u00e9 Franco Montoro International Airport",
#                 "type": "airport",
#                 "height": 2459,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.435556411743164,
#                 "timezone": -3.0,
#                 "longitude": -46.47305679321289,
#                 "airport_id": 2564,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 1,
#     "legs": [
#         {
#             "id": 1125899906851975,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134419,
#             "properties": {
#                 "stops": 0,
#                 "company": "AD",
#                 "codeshare": "",
#                 "equipment": "E95 E90",
#                 "airline_id": 13983
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134419,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Campinas",
#                 "iata": "VCP",
#                 "icao": "SBKP",
#                 "name": "Viracopos International Airport",
#                 "type": "airport",
#                 "height": 2170,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.0074005127,
#                 "timezone": -3.0,
#                 "longitude": -47.1344985962,
#                 "airport_id": 2578,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 1,
#     "legs": [
#         {
#             "id": 1125899906885681,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134455,
#             "properties": {
#                 "stops": 0,
#                 "company": "O6",
#                 "codeshare": "",
#                 "equipment": "318 319 100",
#                 "airline_id": 3764
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134455,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "CGH",
#                 "icao": "SBSP",
#                 "name": "Congonhas Airport",
#                 "type": "airport",
#                 "height": 2631,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.626110076904297,
#                 "timezone": -3.0,
#                 "longitude": -46.65638732910156,
#                 "airport_id": 2618,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 1,
#     "legs": [
#         {
#             "id": 1125899906875818,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134455,
#             "properties": {
#                 "stops": 0,
#                 "company": "JJ",
#                 "codeshare": "",
#                 "equipment": "320 319",
#                 "airline_id": 4867
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134455,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "CGH",
#                 "icao": "SBSP",
#                 "name": "Congonhas Airport",
#                 "type": "airport",
#                 "height": 2631,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.626110076904297,
#                 "timezone": -3.0,
#                 "longitude": -46.65638732910156,
#                 "airport_id": 2618,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 1,
#     "legs": [
#         {
#             "id": 1125899906875696,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134405,
#             "properties": {
#                 "stops": 0,
#                 "company": "JJ",
#                 "codeshare": "",
#                 "equipment": "321 320",
#                 "airline_id": 4867
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134405,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "GRU",
#                 "icao": "SBGR",
#                 "name": "Guarulhos - Governador Andr\u00e9 Franco Montoro International Airport",
#                 "type": "airport",
#                 "height": 2459,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.435556411743164,
#                 "timezone": -3.0,
#                 "longitude": -46.47305679321289,
#                 "airport_id": 2564,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 1,
#     "legs": [
#         {
#             "id": 1125899906871189,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134405,
#             "properties": {
#                 "stops": 0,
#                 "company": "G3",
#                 "codeshare": "",
#                 "equipment": "738 73G",
#                 "airline_id": 1790
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134405,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "GRU",
#                 "icao": "SBGR",
#                 "name": "Guarulhos - Governador Andr\u00e9 Franco Montoro International Airport",
#                 "type": "airport",
#                 "height": 2459,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.435556411743164,
#                 "timezone": -3.0,
#                 "longitude": -46.47305679321289,
#                 "airport_id": 2564,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 2,
#     "legs": [
#         {
#             "id": 1125899906875744,
#             "label": "ROUTE",
#             "end_id": 844424930133315,
#             "start_id": 844424930134405,
#             "properties": {
#                 "stops": 0,
#                 "company": "JJ",
#                 "codeshare": "",
#                 "equipment": "773",
#                 "airline_id": 4867
#             }
#         },
#         {
#             "id": 1125899906851471,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930133315,
#             "properties": {
#                 "stops": 0,
#                 "company": "AF",
#                 "codeshare": "",
#                 "equipment": "772",
#                 "airline_id": 137
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134405,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "GRU",
#                 "icao": "SBGR",
#                 "name": "Guarulhos - Governador Andr\u00e9 Franco Montoro International Airport",
#                 "type": "airport",
#                 "height": 2459,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.435556411743164,
#                 "timezone": -3.0,
#                 "longitude": -46.47305679321289,
#                 "airport_id": 2564,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930133315,
#             "label": "Airport",
#             "properties": {
#                 "dst": "E",
#                 "city": "Paris",
#                 "iata": "CDG",
#                 "icao": "LFPG",
#                 "name": "Charles de Gaulle International Airport",
#                 "type": "airport",
#                 "height": 392,
#                 "source": "OurAirports",
#                 "country": "France",
#                 "latitude": 49.012798,
#                 "timezone": 1.0,
#                 "longitude": 2.55,
#                 "airport_id": 1382,
#                 "tz_database_timezone": "Europe/Paris"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 2,
#     "legs": [
#         {
#             "id": 1125899906885630,
#             "label": "ROUTE",
#             "end_id": 844424930134458,
#             "start_id": 844424930134405,
#             "properties": {
#                 "stops": 0,
#                 "company": "O6",
#                 "codeshare": "",
#                 "equipment": "320 318",
#                 "airline_id": 3764
#             }
#         },
#         {
#             "id": 1125899906875830,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134458,
#             "properties": {
#                 "stops": 0,
#                 "company": "JJ",
#                 "codeshare": "",
#                 "equipment": "320 319",
#                 "airline_id": 4867
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134405,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "GRU",
#                 "icao": "SBGR",
#                 "name": "Guarulhos - Governador Andr\u00e9 Franco Montoro International Airport",
#                 "type": "airport",
#                 "height": 2459,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.435556411743164,
#                 "timezone": -3.0,
#                 "longitude": -46.47305679321289,
#                 "airport_id": 2564,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134458,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Salvador",
#                 "iata": "SSA",
#                 "icao": "SBSV",
#                 "name": "Deputado Luiz Eduardo Magalh\u00e3es International Airport",
#                 "type": "airport",
#                 "height": 64,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -12.9086112976,
#                 "timezone": -3.0,
#                 "longitude": -38.3224983215,
#                 "airport_id": 2621,
#                 "tz_database_timezone": "America/Fortaleza"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 2,
#     "legs": [
#         {
#             "id": 1125899906879708,
#             "label": "ROUTE",
#             "end_id": 844424930134387,
#             "start_id": 844424930134405,
#             "properties": {
#                 "stops": 0,
#                 "company": "LH",
#                 "codeshare": "Y",
#                 "equipment": "320",
#                 "airline_id": 3320
#             }
#         },
#         {
#             "id": 1125899906871095,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134387,
#             "properties": {
#                 "stops": 0,
#                 "company": "G3",
#                 "codeshare": "",
#                 "equipment": "738 73G",
#                 "airline_id": 1790
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134405,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "GRU",
#                 "icao": "SBGR",
#                 "name": "Guarulhos - Governador Andr\u00e9 Franco Montoro International Airport",
#                 "type": "airport",
#                 "height": 2459,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.435556411743164,
#                 "timezone": -3.0,
#                 "longitude": -46.47305679321289,
#                 "airport_id": 2564,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134387,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Curitiba",
#                 "iata": "CWB",
#                 "icao": "SBCT",
#                 "name": "Afonso Pena Airport",
#                 "type": "airport",
#                 "height": 2988,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -25.5284996033,
#                 "timezone": -3.0,
#                 "longitude": -49.1758003235,
#                 "airport_id": 2545,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 2,
#     "legs": [
#         {
#             "id": 1125899906879704,
#             "label": "ROUTE",
#             "end_id": 844424930135746,
#             "start_id": 844424930134405,
#             "properties": {
#                 "stops": 0,
#                 "company": "LA",
#                 "codeshare": "Y",
#                 "equipment": "330 320",
#                 "airline_id": 3200
#             }
#         },
#         {
#             "id": 1125899906854540,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930135746,
#             "properties": {
#                 "stops": 0,
#                 "company": "AR",
#                 "codeshare": "",
#                 "equipment": "737",
#                 "airline_id": 412
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134405,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "GRU",
#                 "icao": "SBGR",
#                 "name": "Guarulhos - Governador Andr\u00e9 Franco Montoro International Airport",
#                 "type": "airport",
#                 "height": 2459,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.435556411743164,
#                 "timezone": -3.0,
#                 "longitude": -46.47305679321289,
#                 "airport_id": 2564,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930135746,
#             "label": "Airport",
#             "properties": {
#                 "dst": "N",
#                 "city": "Buenos Aires",
#                 "iata": "EZE",
#                 "icao": "SAEZ",
#                 "name": "Ministro Pistarini International Airport",
#                 "type": "airport",
#                 "height": 67,
#                 "source": "OurAirports",
#                 "country": "Argentina",
#                 "latitude": -34.8222,
#                 "timezone": -3.0,
#                 "longitude": -58.5358,
#                 "airport_id": 3988,
#                 "tz_database_timezone": "America/Buenos_Aires"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 2,
#     "legs": [
#         {
#             "id": 1125899906885631,
#             "label": "ROUTE",
#             "end_id": 844424930134449,
#             "start_id": 844424930134405,
#             "properties": {
#                 "stops": 0,
#                 "company": "O6",
#                 "codeshare": "",
#                 "equipment": "320 318",
#                 "airline_id": 3764
#             }
#         },
#         {
#             "id": 1125899906875783,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134449,
#             "properties": {
#                 "stops": 0,
#                 "company": "JJ",
#                 "codeshare": "",
#                 "equipment": "320 321",
#                 "airline_id": 4867
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134405,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "GRU",
#                 "icao": "SBGR",
#                 "name": "Guarulhos - Governador Andr\u00e9 Franco Montoro International Airport",
#                 "type": "airport",
#                 "height": 2459,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.435556411743164,
#                 "timezone": -3.0,
#                 "longitude": -46.47305679321289,
#                 "airport_id": 2564,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134449,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Recife",
#                 "iata": "REC",
#                 "icao": "SBRF",
#                 "name": "Guararapes - Gilberto Freyre International Airport",
#                 "type": "airport",
#                 "height": 33,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -8.126489639282227,
#                 "timezone": -3.0,
#                 "longitude": -34.92359924316406,
#                 "airport_id": 2610,
#                 "tz_database_timezone": "America/Fortaleza"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 2,
#     "legs": [
#         {
#             "id": 1125899906885630,
#             "label": "ROUTE",
#             "end_id": 844424930134458,
#             "start_id": 844424930134405,
#             "properties": {
#                 "stops": 0,
#                 "company": "O6",
#                 "codeshare": "",
#                 "equipment": "320 318",
#                 "airline_id": 3764
#             }
#         },
#         {
#             "id": 1125899906871307,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134458,
#             "properties": {
#                 "stops": 0,
#                 "company": "G3",
#                 "codeshare": "",
#                 "equipment": "738",
#                 "airline_id": 1790
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134405,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "GRU",
#                 "icao": "SBGR",
#                 "name": "Guarulhos - Governador Andr\u00e9 Franco Montoro International Airport",
#                 "type": "airport",
#                 "height": 2459,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.435556411743164,
#                 "timezone": -3.0,
#                 "longitude": -46.47305679321289,
#                 "airport_id": 2564,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134458,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Salvador",
#                 "iata": "SSA",
#                 "icao": "SBSV",
#                 "name": "Deputado Luiz Eduardo Magalh\u00e3es International Airport",
#                 "type": "airport",
#                 "height": 64,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -12.9086112976,
#                 "timezone": -3.0,
#                 "longitude": -38.3224983215,
#                 "airport_id": 2621,
#                 "tz_database_timezone": "America/Fortaleza"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 2,
#     "legs": [
#         {
#             "id": 1125899906875743,
#             "label": "ROUTE",
#             "end_id": 844424930134390,
#             "start_id": 844424930134405,
#             "properties": {
#                 "stops": 0,
#                 "company": "JJ",
#                 "codeshare": "",
#                 "equipment": "320",
#                 "airline_id": 4867
#             }
#         },
#         {
#             "id": 1125899906885608,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134390,
#             "properties": {
#                 "stops": 0,
#                 "company": "O6",
#                 "codeshare": "",
#                 "equipment": "100",
#                 "airline_id": 3764
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134405,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "GRU",
#                 "icao": "SBGR",
#                 "name": "Guarulhos - Governador Andr\u00e9 Franco Montoro International Airport",
#                 "type": "airport",
#                 "height": 2459,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.435556411743164,
#                 "timezone": -3.0,
#                 "longitude": -46.47305679321289,
#                 "airport_id": 2564,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134390,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Cuiaba",
#                 "iata": "CGB",
#                 "icao": "SBCY",
#                 "name": "Marechal Rondon Airport",
#                 "type": "airport",
#                 "height": 617,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.6528997421,
#                 "timezone": -4.0,
#                 "longitude": -56.1166992188,
#                 "airport_id": 2548,
#                 "tz_database_timezone": "America/Campo_Grande"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 2,
#     "legs": [
#         {
#             "id": 1125899906885635,
#             "label": "ROUTE",
#             "end_id": 844424930134430,
#             "start_id": 844424930134405,
#             "properties": {
#                 "stops": 0,
#                 "company": "O6",
#                 "codeshare": "",
#                 "equipment": "318",
#                 "airline_id": 3764
#             }
#         },
#         {
#             "id": 1125899906871229,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134430,
#             "properties": {
#                 "stops": 0,
#                 "company": "G3",
#                 "codeshare": "",
#                 "equipment": "738",
#                 "airline_id": 1790
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134405,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "GRU",
#                 "icao": "SBGR",
#                 "name": "Guarulhos - Governador Andr\u00e9 Franco Montoro International Airport",
#                 "type": "airport",
#                 "height": 2459,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.435556411743164,
#                 "timezone": -3.0,
#                 "longitude": -46.47305679321289,
#                 "airport_id": 2564,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134430,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Maceio",
#                 "iata": "MCZ",
#                 "icao": "SBMO",
#                 "name": "Zumbi dos Palmares Airport",
#                 "type": "airport",
#                 "height": 387,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -9.510809898376465,
#                 "timezone": -3.0,
#                 "longitude": -35.79169845581055,
#                 "airport_id": 2590,
#                 "tz_database_timezone": "America/Fortaleza"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 2,
#     "legs": [
#         {
#             "id": 1125899906885638,
#             "label": "ROUTE",
#             "end_id": 844424930134400,
#             "start_id": 844424930134405,
#             "properties": {
#                 "stops": 0,
#                 "company": "O6",
#                 "codeshare": "",
#                 "equipment": "320 318",
#                 "airline_id": 3764
#             }
#         },
#         {
#             "id": 1125899906875663,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134400,
#             "properties": {
#                 "stops": 0,
#                 "company": "JJ",
#                 "codeshare": "",
#                 "equipment": "321 319",
#                 "airline_id": 4867
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134405,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "GRU",
#                 "icao": "SBGR",
#                 "name": "Guarulhos - Governador Andr\u00e9 Franco Montoro International Airport",
#                 "type": "airport",
#                 "height": 2459,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.435556411743164,
#                 "timezone": -3.0,
#                 "longitude": -46.47305679321289,
#                 "airport_id": 2564,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134400,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Fortaleza",
#                 "iata": "FOR",
#                 "icao": "SBFZ",
#                 "name": "Pinto Martins International Airport",
#                 "type": "airport",
#                 "height": 82,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -3.776279926300049,
#                 "timezone": -3.0,
#                 "longitude": -38.53260040283203,
#                 "airport_id": 2559,
#                 "tz_database_timezone": "America/Fortaleza"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 2,
#     "legs": [
#         {
#             "id": 1125899906885639,
#             "label": "ROUTE",
#             "end_id": 844424930134397,
#             "start_id": 844424930134405,
#             "properties": {
#                 "stops": 0,
#                 "company": "O6",
#                 "codeshare": "",
#                 "equipment": "318 320",
#                 "airline_id": 3764
#             }
#         },
#         {
#             "id": 1125899906885617,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134397,
#             "properties": {
#                 "stops": 0,
#                 "company": "O6",
#                 "codeshare": "",
#                 "equipment": "318",
#                 "airline_id": 3764
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134405,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "GRU",
#                 "icao": "SBGR",
#                 "name": "Guarulhos - Governador Andr\u00e9 Franco Montoro International Airport",
#                 "type": "airport",
#                 "height": 2459,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.435556411743164,
#                 "timezone": -3.0,
#                 "longitude": -46.47305679321289,
#                 "airport_id": 2564,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134397,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Florianopolis",
#                 "iata": "FLN",
#                 "icao": "SBFL",
#                 "name": "Herc\u00edlio Luz International Airport",
#                 "type": "airport",
#                 "height": 16,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -27.670278549194336,
#                 "timezone": -3.0,
#                 "longitude": -48.5525016784668,
#                 "airport_id": 2555,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 2,
#     "legs": [
#         {
# ...
#                 "dst": "S",
#                 "city": "Juazeiro Do Norte",
#                 "iata": "JDO",
#                 "icao": "SBJU",
#                 "name": "Orlando Bezerra de Menezes Airport",
#                 "type": "airport",
#                 "height": 1392,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -7.21895980835,
#                 "timezone": -3.0,
#                 "longitude": -39.270099639899996,
#                 "airport_id": 6034,
#                 "tz_database_timezone": "America/Fortaleza"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 2,
#     "legs": [
#         {
#             "id": 1125899906885635,
#             "label": "ROUTE",
#             "end_id": 844424930134430,
#             "start_id": 844424930134405,
#             "properties": {
#                 "stops": 0,
#                 "company": "O6",
#                 "codeshare": "",
#                 "equipment": "318",
#                 "airline_id": 3764
#             }
#         },
#         {
#             "id": 1125899906885650,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134430,
#             "properties": {
#                 "stops": 0,
#                 "company": "O6",
#                 "codeshare": "",
#                 "equipment": "318",
#                 "airline_id": 3764
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134405,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "GRU",
#                 "icao": "SBGR",
#                 "name": "Guarulhos - Governador Andr\u00e9 Franco Montoro International Airport",
#                 "type": "airport",
#                 "height": 2459,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.435556411743164,
#                 "timezone": -3.0,
#                 "longitude": -46.47305679321289,
#                 "airport_id": 2564,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134430,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Maceio",
#                 "iata": "MCZ",
#                 "icao": "SBMO",
#                 "name": "Zumbi dos Palmares Airport",
#                 "type": "airport",
#                 "height": 387,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -9.510809898376465,
#                 "timezone": -3.0,
#                 "longitude": -35.79169845581055,
#                 "airport_id": 2590,
#                 "tz_database_timezone": "America/Fortaleza"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 2,
#     "legs": [
#         {
#             "id": 1125899906885634,
#             "label": "ROUTE",
#             "end_id": 844424930134437,
#             "start_id": 844424930134405,
#             "properties": {
#                 "stops": 0,
#                 "company": "O6",
#                 "codeshare": "",
#                 "equipment": "320",
#                 "airline_id": 3764
#             }
#         },
#         {
#             "id": 1125899906871238,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134437,
#             "properties": {
#                 "stops": 0,
#                 "company": "G3",
#                 "codeshare": "",
#                 "equipment": "738 73G",
#                 "airline_id": 1790
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134405,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "GRU",
#                 "icao": "SBGR",
#                 "name": "Guarulhos - Governador Andr\u00e9 Franco Montoro International Airport",
#                 "type": "airport",
#                 "height": 2459,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.435556411743164,
#                 "timezone": -3.0,
#                 "longitude": -46.47305679321289,
#                 "airport_id": 2564,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134437,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Natal",
#                 "iata": "NAT",
#                 "icao": "SBSG",
#                 "name": "Governador Alu\u00edzio Alves International Airport",
#                 "type": "airport",
#                 "height": 272,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -5.768056,
#                 "timezone": -3.0,
#                 "longitude": -35.376111,
#                 "airport_id": 2597,
#                 "tz_database_timezone": "America/Fortaleza"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 2,
#     "legs": [
#         {
#             "id": 1125899906885632,
#             "label": "ROUTE",
#             "end_id": 844424930134439,
#             "start_id": 844424930134405,
#             "properties": {
#                 "stops": 0,
#                 "company": "O6",
#                 "codeshare": "",
#                 "equipment": "100 318",
#                 "airline_id": 3764
#             }
#         },
#         {
#             "id": 1125899906875774,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134439,
#             "properties": {
#                 "stops": 0,
#                 "company": "JJ",
#                 "codeshare": "",
#                 "equipment": "320",
#                 "airline_id": 4867
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134405,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "GRU",
#                 "icao": "SBGR",
#                 "name": "Guarulhos - Governador Andr\u00e9 Franco Montoro International Airport",
#                 "type": "airport",
#                 "height": 2459,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.435556411743164,
#                 "timezone": -3.0,
#                 "longitude": -46.47305679321289,
#                 "airport_id": 2564,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134439,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Porto Alegre",
#                 "iata": "POA",
#                 "icao": "SBPA",
#                 "name": "Salgado Filho Airport",
#                 "type": "airport",
#                 "height": 11,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -29.994400024414062,
#                 "timezone": -3.0,
#                 "longitude": -51.1713981628418,
#                 "airport_id": 2599,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 2,
#     "legs": [
#         {
#             "id": 1125899906907779,
#             "label": "ROUTE",
#             "end_id": 844424930134470,
#             "start_id": 844424930134405,
#             "properties": {
#                 "stops": 0,
#                 "company": "Y8",
#                 "codeshare": "",
#                 "equipment": "EM2",
#                 "airline_id": 16725
#             }
#         },
#         {
#             "id": 1125899906875836,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930134470,
#             "properties": {
#                 "stops": 0,
#                 "company": "JJ",
#                 "codeshare": "",
#                 "equipment": "320",
#                 "airline_id": 4867
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134405,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "GRU",
#                 "icao": "SBGR",
#                 "name": "Guarulhos - Governador Andr\u00e9 Franco Montoro International Airport",
#                 "type": "airport",
#                 "height": 2459,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.435556411743164,
#                 "timezone": -3.0,
#                 "longitude": -46.47305679321289,
#                 "airport_id": 2564,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134470,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Uberlandia",
#                 "iata": "UDI",
#                 "icao": "SBUL",
#                 "name": "Ten. Cel. Aviador C\u00e9sar Bombonato Airport",
#                 "type": "airport",
#                 "height": 3094,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -18.883612,
#                 "timezone": -3.0,
#                 "longitude": -48.225277,
#                 "airport_id": 2633,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }
# {
#     "hops": 2,
#     "legs": [
#         {
#             "id": 1125899906901031,
#             "label": "ROUTE",
#             "end_id": 844424930135345,
#             "start_id": 844424930134405,
#             "properties": {
#                 "stops": 0,
#                 "company": "US",
#                 "codeshare": "",
#                 "equipment": "777",
#                 "airline_id": 5265
#             }
#         },
#         {
#             "id": 1125899906847606,
#             "label": "ROUTE",
#             "end_id": 844424930134373,
#             "start_id": 844424930135345,
#             "properties": {
#                 "stops": 0,
#                 "company": "AA",
#                 "codeshare": "",
#                 "equipment": "763 757",
#                 "airline_id": 24
#             }
#         }
#     ],
#     "airports": [
#         {
#             "id": 844424930134405,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Sao Paulo",
#                 "iata": "GRU",
#                 "icao": "SBGR",
#                 "name": "Guarulhos - Governador Andr\u00e9 Franco Montoro International Airport",
#                 "type": "airport",
#                 "height": 2459,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -23.435556411743164,
#                 "timezone": -3.0,
#                 "longitude": -46.47305679321289,
#                 "airport_id": 2564,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         },
#         {
#             "id": 844424930135345,
#             "label": "Airport",
#             "properties": {
#                 "dst": "A",
#                 "city": "Miami",
#                 "iata": "MIA",
#                 "icao": "KMIA",
#                 "name": "Miami International Airport",
#                 "type": "airport",
#                 "height": 8,
#                 "source": "OurAirports",
#                 "country": "United States",
#                 "latitude": 25.79319953918457,
#                 "timezone": -5.0,
#                 "longitude": -80.29060363769531,
#                 "airport_id": 3576,
#                 "tz_database_timezone": "America/New_York"
#             }
#         },
#         {
#             "id": 844424930134373,
#             "label": "Airport",
#             "properties": {
#                 "dst": "S",
#                 "city": "Brasilia",
#                 "iata": "BSB",
#                 "icao": "SBBR",
#                 "name": "Presidente Juscelino Kubistschek International Airport",
#                 "type": "airport",
#                 "height": 3497,
#                 "source": "OurAirports",
#                 "country": "Brazil",
#                 "latitude": -15.86916732788086,
#                 "timezone": -3.0,
#                 "longitude": -47.920833587646484,
#                 "airport_id": 2531,
#                 "tz_database_timezone": "America/Sao_Paulo"
#             }
#         }
#     ]
# }

# %% [markdown]
# # Fecha conexão e derruba container

# %%
conn.commit()
cur.close()
conn.close()

# %%
# !docker compose down
# Out:
#  Container postgres-age  Stopping
#  Container postgres-age  Stopped
#  Container postgres-age  Removing
#  Container postgres-age  Removed
#  Network atividade9_default  Removing
#  Network atividade9_default  Removed
