# %%
############## Importar os módulos necessários para o Notebook:
import matplotlib.pyplot as plt
import pandas.io.sql as psql
from ipywidgets import interact  ##-- Interactors
import ipywidgets as widgets     #---
from sqlalchemy import create_engine, text

############## Conectar com um servidor SQL ###################### --> Postgres
# %load_ext sql

# Connection format: %sql dialect+driver://username:password@host:port/database
engine = create_engine('postgresql://postgres:pgadmin@localhost/fapcov2103')
# %sql postgresql://postgres:pgadmin@localhost/fapcov2103
# %config SqlMagic.displaylimit=None

# %sql SET Search_Path To D2;
# Out:
# Connecting to 'postgresql://postgres:***@localhost/fapcov2103'
# displaylimit: Value None will be treated as 0 (no limit)
# Running query in 'postgresql://postgres:***@localhost/fapcov2103'
# ++
# ||
# ++
# ++

# %%
# %%sql
# select * from examlabs limit 2
# Out:
# Running query in 'postgresql://postgres:***@localhost/fapcov2103'
# 2 rows affected.
# +----------------------------------+----------------------------------+------------+-----------+-----------+-----------------+--------------+------------+--------------------+-------------+--------------+------------------+
# |           id_paciente            |          id_atendimento          | dt_coleta  | de_origem |  de_exame |    de_analito   | de_resultado | cd_unidade | cd_valorreferencia | de_hospital | de_resultnum | de_resultadocorr |
# +----------------------------------+----------------------------------+------------+-----------+-----------+-----------------+--------------+------------+--------------------+-------------+--------------+------------------+
# | DFF252C84D4AFBC754A45C0152435715 | 6EC6CDFBC0C8C71634463249FA439B81 | 2020-10-16 |    UTI    | hemograma | neutrófilos (%) |     79,0     |    None    |        None        |     HSL     |     79.0     |       79,0       |
# | 144BBEB46DB9D292843D50A4B5B9CFE0 | D073DC83098193A392D5EF65F04BFABE | 2020-07-28 |    UTI    |    tgo    |    ast (tgo)    |      25      |    U/L     |       Até 32       |     HSL     |     25.0     |        25        |
# +----------------------------------+----------------------------------+------------+-----------+-----------+-----------------+--------------+------------+--------------------+-------------+--------------+------------------+

# %% [markdown]
# ## Pré-Processamento dos Dados

# %% [markdown]
# Materialização e Visão dos Exames (Pivoteamento)

# %%
# %%sql
# -- Despreza view materializada eventualmente criada
# DROP MATERIALIZED VIEW IF EXISTS d2.view_colesterol_pivot CASCADE;
#
# -- Criação da view materializada do exercício
# CREATE MATERIALIZED VIEW d2.view_colesterol_pivot AS
# SELECT
#     id_atendimento,
#     id_paciente,
#     dt_coleta,
#     de_hospital,
#
#     -- LDL: Encontrado como 'ldl colesterol' (excluímos 'vldl')
#     MAX(CASE
#         WHEN de_analito ILIKE '%ldl%'
#              AND de_analito NOT ILIKE '%vldl%'
#         THEN de_resultnum END) AS val_ldl,
#
#     -- HDL: encontrado como 'hdl-colesterol' (excluímos 'não-hdl')
#     MAX(CASE
#         WHEN de_analito ILIKE '%hdl%'
#              AND de_analito NOT ILIKE '%não%hdl%'
#              AND de_analito NOT ILIKE '%nao%hdl%'
#         THEN de_resultnum END) AS val_hdl,
#
#     -- VLDL: encontrado como 'vldl-colesterol'
#     MAX(CASE
#         WHEN de_analito ILIKE '%vldl%'
#         THEN de_resultnum END) AS val_vldl,
#
#     -- Não HDL: Encontrado como 'colesterol não-hdl, soro'
#     MAX(CASE
#         WHEN de_analito ILIKE '%não%hdl%'
#              OR de_analito ILIKE '%nao%hdl%'
#         THEN de_resultnum END) AS val_nao_hdl,
#
#     -- Total: Encontrado como 'colesterol total' (exigimos '%colesterol total%')
#     MAX(CASE
#         WHEN de_analito ILIKE '%colesterol total%'
#         THEN de_resultnum END) AS val_total
#
# FROM d2.examlabs
# -- Filtro otimizado para linhas relevantes antes do pivot
# WHERE
#     de_analito ILIKE '%colesterol%'
#     OR de_analito ILIKE '%ldl%'
#     OR de_analito ILIKE '%hdl%'
#     OR de_analito ILIKE '%vldl%'
# GROUP BY id_atendimento, id_paciente, dt_coleta, de_hospital;
#
# -- Recriação do índice para ajudar nas buscas
# CREATE INDEX idx_view_colesterol ON d2.view_colesterol_pivot(id_atendimento);
# Out:
# Running query in 'postgresql://postgres:***@localhost/fapcov2103'
# 2013 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
# SELECT * FROM view_colesterol_pivot limit 10;
# Out:
# Running query in 'postgresql://postgres:***@localhost/fapcov2103'
# 10 rows affected.
# +----------------------------------+----------------------------------+------------+-------------+---------+---------+----------+-------------+-----------+
# |          id_atendimento          |           id_paciente            | dt_coleta  | de_hospital | val_ldl | val_hdl | val_vldl | val_nao_hdl | val_total |
# +----------------------------------+----------------------------------+------------+-------------+---------+---------+----------+-------------+-----------+
# | F53AE0CB2B0303BA651BAD79826F485E | 6ADB8777DF2FF074B6C0D6FF199253D8 | 2020-11-24 |     HSL     |  102.0  |   75.0  |   29.0   |    131.0    |   206.0   |
# | 2763EBBD359A77B02DDB812D96303438 | A33FEAD5BC95E540D33D544A3317F7A6 | 2020-07-29 |     HSL     |  103.0  |   42.0  |   None   |     None    |   168.0   |
# | 26E6FBC0B77485D4E520676012D95B1D | 8445CC198063CBA2FAC67192094C0F54 | 2020-10-10 |     HSL     |  114.0  |   50.0  |   None   |     None    |   192.0   |
# | 9CB72B5B5BF215DDBBCC924DC19B3F4F | E3D7C45E6FAC2DB67727E0C5260D74F2 | 2020-11-07 |     HSL     |   96.0  |   58.0  |   11.0   |    107.0    |   165.0   |
# | AEE10D1D2962EC2B7F7F9CD2AA5E76EE | 266B8868D10DCB6D665B42C71D2282CC | 2020-10-31 |     HSL     |  170.0  |   18.0  |   None   |     None    |   264.0   |
# | 43BA837CB99F6CD1F7FFA51E48AC0FFA | C103F8BE6DD2E343EF2F3EE66C22F742 | 2020-11-07 |     HSL     |  120.0  |   51.0  |   11.0   |    131.0    |   182.0   |
# | F97C5A04BA5A4226EF9048236E39B81E | EA1E5BE3B0BC4F01DA3DBBD704FB1179 | 2020-09-21 |     HSL     |   None  |   58.0  |   None   |     None    |   179.0   |
# | B972D067E14809E474281F4907D9EE32 | 322F62469C5E3C7DC3E58F5A4D1EA399 | 2020-12-15 |     HSL     |   77.0  |   46.0  |   19.0   |     96.0    |   142.0   |
# | 7F0F1E5AC2743F5F3FD66D7B345E7E9C | 8B529A34361525D285DF1358FD960787 | 2020-10-30 |     HSL     |   78.0  |   41.0  |   18.0   |     96.0    |   137.0   |
# | 2A96C2F4E43DF70075F0250A2B41CA5E | 19976D4349E3502F691CF896666E41AB | 2020-07-24 |     HSL     |   None  |   62.0  |   None   |    107.0    |   169.0   |
# +----------------------------------+----------------------------------+------------+-------------+---------+---------+----------+-------------+-----------+

# %% [markdown]
# ## Criação da Tabela de Referência

# %%
# %%sql
# DROP TABLE IF EXISTS d2.ref_colesterol_limites;
#
# CREATE TABLE d2.ref_colesterol_limites (
#     tipo_referencia text,
#     limite_ldl float8,
#     limite_hdl float8,
#     limite_vldl float8,
#     limite_nao_hdl float8,
#     limite_total float8
# );
#
# -- Inserindo os valores de referência da SBC
# -- LDL<130, HDL>=40, VLDL<30, Não HDL<160, Total<190
# INSERT INTO d2.ref_colesterol_limites
# VALUES ('SBC_2024', 130, 40, 30, 160, 190);
# Out:
# Running query in 'postgresql://postgres:***@localhost/fapcov2103'
# 1 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
# select * from d2.ref_colesterol_limites
# Out:
# Running query in 'postgresql://postgres:***@localhost/fapcov2103'
# 1 rows affected.
# +-----------------+------------+------------+-------------+----------------+--------------+
# | tipo_referencia | limite_ldl | limite_hdl | limite_vldl | limite_nao_hdl | limite_total |
# +-----------------+------------+------------+-------------+----------------+--------------+
# |     SBC_2024    |   130.0    |    40.0    |     30.0    |     160.0      |    190.0     |
# +-----------------+------------+------------+-------------+----------------+--------------+

# %% [markdown]
# ## Classificação

# %%
# %%sql
# CREATE OR REPLACE VIEW d2.view_colesterol_classificado AS
# SELECT
#     p.*,
#     CASE
#         -- Verifica se ALGUM analito viola a regra (regra de exclusão)
#         WHEN (p.val_ldl >= r.limite_ldl) THEN 'FORA'
#         WHEN (p.val_hdl <  r.limite_hdl) THEN 'FORA'
#         WHEN (p.val_vldl >= r.limite_vldl) THEN 'FORA'
#         WHEN (p.val_nao_hdl >= r.limite_nao_hdl) THEN 'FORA'
#         WHEN (p.val_total >= r.limite_total) THEN 'FORA'
#         -- Se passou por tudo e tem valores, está dentro
#         ELSE 'DENTRO'
#     END AS status_referencia
# FROM d2.view_colesterol_pivot p
# CROSS JOIN d2.ref_colesterol_limites r
# WHERE r.tipo_referencia = 'SBC_2024'
#   -- Garante que pelo menos um valor de colesterol existe para classificar
#   AND COALESCE(val_ldl, val_hdl, val_vldl, val_nao_hdl, val_total) IS NOT NULL;
# Out:
# Running query in 'postgresql://postgres:***@localhost/fapcov2103'
# ++
# ||
# ++
# ++

# %%
# %%sql
# SELECT id_paciente, status_referencia FROM view_colesterol_classificado limit 10;
# Out:
# Running query in 'postgresql://postgres:***@localhost/fapcov2103'
# 10 rows affected.
# +----------------------------------+-------------------+
# |           id_paciente            | status_referencia |
# +----------------------------------+-------------------+
# | 6ADB8777DF2FF074B6C0D6FF199253D8 |        FORA       |
# | A33FEAD5BC95E540D33D544A3317F7A6 |       DENTRO      |
# | 8445CC198063CBA2FAC67192094C0F54 |        FORA       |
# | E3D7C45E6FAC2DB67727E0C5260D74F2 |       DENTRO      |
# | 266B8868D10DCB6D665B42C71D2282CC |        FORA       |
# | C103F8BE6DD2E343EF2F3EE66C22F742 |       DENTRO      |
# | EA1E5BE3B0BC4F01DA3DBBD704FB1179 |       DENTRO      |
# | 322F62469C5E3C7DC3E58F5A4D1EA399 |       DENTRO      |
# | 8B529A34361525D285DF1358FD960787 |       DENTRO      |
# | 19976D4349E3502F691CF896666E41AB |       DENTRO      |
# +----------------------------------+-------------------+

# %% [markdown]
# ## Contagem por Classe

# %% [markdown]
# Essa parte é referente ao item abaixo do exercício:
#
# A) Contabilize quantos exames estão com ao menos um analito fora do seu
# correspondente valor de referência e quantos estão com todos os analitos
# dentro dos valores de referência;

# %%
# %%sql
# SELECT
#     status_referencia,
#     COUNT(*) as qtd_exames
# FROM d2.view_colesterol_classificado
# GROUP BY status_referencia;
# Out:
# Running query in 'postgresql://postgres:***@localhost/fapcov2103'
# 2 rows affected.
# +-------------------+------------+
# | status_referencia | qtd_exames |
# +-------------------+------------+
# |        FORA       |    1064    |
# |       DENTRO      |    949     |
# +-------------------+------------+

# %% [markdown]
# ## Amostragem Estratificada

# %% [markdown]
# Essa parte é referente ao item abaixo do exercício:
#
# B) Gere uma amostragem que contenha 25% dos exames fora e 10% dos
# exames dentro dos valores de referência.

# %%
# %%sql
# SELECT *
# FROM (
#     -- Amostra 10% dos que estão DENTRO
#     SELECT
#         id_atendimento,
#         'Amostra DENTRO (10%)' as origem_amostra,
#         val_total, val_ldl, val_hdl -- colunas de interesse
#     FROM d2.view_colesterol_classificado
#     WHERE status_referencia = 'DENTRO'
#     AND random() < 0.10
# ) dentro
#
# UNION ALL
#
# SELECT *
# FROM (
#     -- Amostra 25% dos que estão FORA
#     SELECT
#         id_atendimento,
#         'Amostra FORA (25%)' as origem_amostra,
#         val_total, val_ldl, val_hdl
#     FROM d2.view_colesterol_classificado
#     WHERE status_referencia = 'FORA'
#     AND random() < 0.25
# ) fora;
# Out:
# Running query in 'postgresql://postgres:***@localhost/fapcov2103'
# 349 rows affected.
# +----------------------------------+----------------------+-----------+---------+---------+
# |          id_atendimento          |    origem_amostra    | val_total | val_ldl | val_hdl |
# +----------------------------------+----------------------+-----------+---------+---------+
# | 4199313AE56C5201AAE89A7B78623A96 | Amostra DENTRO (10%) |   130.0   |   64.0  |   40.0  |
# | 0C13007154A0120FE17B6D04DECFB8DD | Amostra DENTRO (10%) |   177.0   |  102.0  |   56.0  |
# | D662092DC9B6F4EF68919C0589FD66F4 | Amostra DENTRO (10%) |   133.0   |   66.0  |   50.0  |
# | 214A8EBF0CD993EF240A519255A39038 | Amostra DENTRO (10%) |   181.0   |   91.0  |   68.0  |
# | 55404CBCAF2CEE26E392BADEC2B60B5E | Amostra DENTRO (10%) |   182.0   |  115.0  |   42.0  |
# | 78AB6B0A7D9049B245448B3A74974ED4 | Amostra DENTRO (10%) |   158.0   |   None  |   51.0  |
# | 26D950D011B5EA7E1BE606DB8BC71713 | Amostra DENTRO (10%) |   147.0   |   90.0  |   40.0  |
# | 1A119F0CDC76890B531E549358920E3D | Amostra DENTRO (10%) |   171.0   |   91.0  |   64.0  |
# | 9B5CCDC1FFBBD1A114259B6318A6AE70 | Amostra DENTRO (10%) |   115.0   |   54.0  |   47.0  |
# | 3A65B72DBCFA6F25E5705088FC108FFD | Amostra DENTRO (10%) |   165.0   |   75.0  |   76.0  |
# | 7C4D46257F95A1021063FED4FD003F42 | Amostra DENTRO (10%) |   188.0   |  123.0  |   48.0  |
# | C50C0F8C37E5FEEE30561F6884DBCFA9 | Amostra DENTRO (10%) |   149.0   |   75.0  |   58.0  |
# | C03994F97E6727F4072EC1392A10211A | Amostra DENTRO (10%) |   181.0   |   None  |   67.0  |
# | 3123A458D2F861A637E9669F2288480B | Amostra DENTRO (10%) |   165.0   |   81.0  |   69.0  |
# | 225388C72F20A57E651464474B598D95 | Amostra DENTRO (10%) |   127.0   |   69.0  |   43.0  |
# | F152B083ECD9598E43423E9106B4E153 | Amostra DENTRO (10%) |   185.0   |  116.0  |   50.0  |
# | C68FCB846168F2446398FB0FA7B4AA69 | Amostra DENTRO (10%) |   127.0   |   57.0  |   51.0  |
# | 6985876F6753C28E43B35A32E39FE8B9 | Amostra DENTRO (10%) |   177.0   |   87.0  |   52.0  |
# | BB23C8EDE6A4317F1CBA62CAED573D1D | Amostra DENTRO (10%) |   187.0   |  113.0  |   60.0  |
# | 548AAB6A2D30B6D1B8EA96D43D0F47D7 | Amostra DENTRO (10%) |   124.0   |   51.0  |   53.0  |
# | EC643680B21106AE63977B6A3A689F4F | Amostra DENTRO (10%) |   180.0   |   98.0  |   67.0  |
# | 656CB0D652F5603FD400E98A1D543B59 | Amostra DENTRO (10%) |   178.0   |  103.0  |   49.0  |
# | 10300288E0D0BCA07CAD4F99DF56CF6D | Amostra DENTRO (10%) |   158.0   |   78.0  |   66.0  |
# | 0A25A7E9DCBB807101A99010B6D844C2 | Amostra DENTRO (10%) |   112.0   |   34.0  |   52.0  |
# | 44FA3A49E12F70C6C79BB52ACCE69A9F | Amostra DENTRO (10%) |   152.0   |   83.0  |   50.0  |
# | 2292970DB42DB92A5FE5DA0B7938F610 | Amostra DENTRO (10%) |   171.0   |  105.0  |   46.0  |
# | 22250792367036FF73F7FE1BBC5F2836 | Amostra DENTRO (10%) |   146.0   |   76.0  |   47.0  |
# | 437B9C7BC2E7C8627E9EECC346F50958 | Amostra DENTRO (10%) |   149.0   |   None  |   None  |
# | 26769CCD4256FD3CCB222FB65A71397F | Amostra DENTRO (10%) |   174.0   |  105.0  |   52.0  |
# | 305C30AD7ADA7259DC10B347D73A42E4 | Amostra DENTRO (10%) |    86.0   |   28.0  |   44.0  |
# | 918CF90D19BB2F118C810BB4506E74BD | Amostra DENTRO (10%) |   173.0   |  108.0  |   47.0  |
# | 56F1F60FBB3C077B8022992A826FE345 | Amostra DENTRO (10%) |   136.0   |   None  |   40.0  |
# | EA9CE4889F6E30A9BD29A24210E40FA5 | Amostra DENTRO (10%) |   161.0   |   88.0  |   55.0  |
# | D46FC4244FA2FC022B021A4785DE6641 | Amostra DENTRO (10%) |   115.0   |   43.0  |   47.0  |
# | 08F85FA11348B2A78090A092AC343BDB | Amostra DENTRO (10%) |   141.0   |   54.0  |   64.0  |
# | 41789CCE14DEB7CE352ED122339FD9AA | Amostra DENTRO (10%) |   180.0   |  103.0  |   61.0  |
# | B4169E675DDDB0D16D7D86342C94E87D | Amostra DENTRO (10%) |   138.0   |   67.0  |   52.0  |
# | E84EB7583F4AD59ABCF5E7AA1276F20D | Amostra DENTRO (10%) |   153.0   |   65.0  |   71.0  |
# | DA3401408E9C2CF0917F29850E7B475B | Amostra DENTRO (10%) |   124.0   |   65.0  |   44.0  |
# | B0C3E185B11C0D0EC40FE34792DC3772 | Amostra DENTRO (10%) |   184.0   |  118.0  |   46.0  |
# | 6F4DF55E84DFD3F5D7440AB962F79E8F | Amostra DENTRO (10%) |   186.0   |   94.0  |   63.0  |
# | 62426B34D4E21A4CDBFA763D3C156385 | Amostra DENTRO (10%) |   164.0   |   87.0  |   61.0  |
# | FBC05E979A2728715B91AD399FE68ED9 | Amostra DENTRO (10%) |   116.0   |   38.0  |   63.0  |
# | 99990570BA5245739EA3A8965A547F04 | Amostra DENTRO (10%) |   102.0   |   44.0  |   44.0  |
# | CEB714509D8A555D05110BEF833DA362 | Amostra DENTRO (10%) |   158.0   |   95.0  |   42.0  |
# | E203B9E75A2F9401094A3A37E44FB634 | Amostra DENTRO (10%) |   167.0   |   94.0  |   60.0  |
# | 065F6C830D0829B58AB70EF0B1C2901D | Amostra DENTRO (10%) |   168.0   |   94.0  |   60.0  |
# | 122F735A24B49C18DEB6BB23898E8F39 | Amostra DENTRO (10%) |   189.0   |  102.0  |   54.0  |
# | A4CAD43037D3D43DC18A87C555C59F6B | Amostra DENTRO (10%) |   118.0   |   50.0  |   51.0  |
# | 3DAA1097F7F89CAF0ABF1709E096FC07 | Amostra DENTRO (10%) |   169.0   |  103.0  |   45.0  |
# | 1A91D6C0A4F7F5753034A51DEAA09698 | Amostra DENTRO (10%) |   142.0   |   51.0  |   68.0  |
# | C6EE23C4AD7D16561743114E7858CC1C | Amostra DENTRO (10%) |   161.0   |   81.0  |   66.0  |
# | BE133687FCEC9BDA82E0B8C217FBE443 | Amostra DENTRO (10%) |   157.0   |   75.0  |   68.0  |
# | 662AB42FB85F9C1E40BB3668DA17D686 | Amostra DENTRO (10%) |   138.0   |   67.0  |   53.0  |
# | 2B5E2C18B6B67F04A03650A185F45E75 | Amostra DENTRO (10%) |   146.0   |   41.0  |   91.0  |
# | 2FF930E1DFF61442A539B9B3510CED87 | Amostra DENTRO (10%) |   180.0   |   51.0  |  107.0  |
# | 50EF20749DD0DAC533BAE7030671E101 | Amostra DENTRO (10%) |   174.0   |   88.0  |   71.0  |
# | A7C05152A0F7B6740575A7B3DD533EB8 | Amostra DENTRO (10%) |   178.0   |  108.0  |   48.0  |
# | FE36D4B800EBDA55F2AFE724E925F9D6 | Amostra DENTRO (10%) |   187.0   |  128.0  |   45.0  |
# | DF432832DB0920808FA72ACF1A3F9387 | Amostra DENTRO (10%) |   187.0   |  114.0  |   46.0  |
# | 100A3F5AEE4FD41C109C797918841AD6 | Amostra DENTRO (10%) |   173.0   |   92.0  |   58.0  |
# | 6AA054F1E7FF4A8F17CE11E3F01E4E8A | Amostra DENTRO (10%) |   146.0   |   69.0  |   61.0  |
# | BD616521F1462359BB7BB50A5CE415CE | Amostra DENTRO (10%) |   136.0   |   83.0  |   40.0  |
# | 5F0650C213F2205E5DD47F83C571CCB2 | Amostra DENTRO (10%) |   183.0   |   98.0  |   72.0  |
# | CBFE4D97FC28684C5B5B975D34176298 | Amostra DENTRO (10%) |   129.0   |   66.0  |   47.0  |
# | 7E067B939BED50083DD5854FAC289C23 | Amostra DENTRO (10%) |   180.0   |  110.0  |   53.0  |
# | 501B59717D8587A9EFAA5EF4E37E748D | Amostra DENTRO (10%) |   167.0   |   75.0  |   77.0  |
# | DF3003BEC13C1E65746EB271E06F2DDA | Amostra DENTRO (10%) |   144.0   |   69.0  |   56.0  |
# | 9004AEA79BC855241F587CAFAE035F8C | Amostra DENTRO (10%) |   124.0   |   42.0  |   61.0  |
# | E45B51A99D5D4AC890BCB57B5C5C5614 | Amostra DENTRO (10%) |   149.0   |   57.0  |   81.0  |
# | 9032060F0FC3CA977C6F8642543FA224 | Amostra DENTRO (10%) |   173.0   |   75.0  |   81.0  |
# | 690BBBE9FE7629B5440D2C6E26483551 | Amostra DENTRO (10%) |   169.0   |   97.0  |   52.0  |
# | 3128AE29BF2E1195F7314EFA5932669F | Amostra DENTRO (10%) |   141.0   |   77.0  |   44.0  |
# | EB553608948ADA7529EF9EB781FF92E2 | Amostra DENTRO (10%) |   189.0   |  116.0  |   49.0  |
# | 544A46785D2645919608476DAD029B25 | Amostra DENTRO (10%) |   183.0   |  106.0  |   65.0  |
# | 79EE0FBA384C17065352F184F42930A4 | Amostra DENTRO (10%) |   177.0   |   70.0  |   87.0  |
# | F68B44D356482E7F909A30783694EDB8 | Amostra DENTRO (10%) |   139.0   |   68.0  |   55.0  |
# | C4955C8FC5067AD7AA13B2EEC99E4D5D | Amostra DENTRO (10%) |   151.0   |   82.0  |   43.0  |
# | F9D3E0809104494D672078B3C7B2D303 | Amostra DENTRO (10%) |   149.0   |   84.0  |   51.0  |
# | 26E6FBC0B77485D4E520676012D95B1D |  Amostra FORA (25%)  |   192.0   |  114.0  |   50.0  |
# | AEE10D1D2962EC2B7F7F9CD2AA5E76EE |  Amostra FORA (25%)  |   264.0   |  170.0  |   18.0  |
# | ED95EA44875CD218A5D0928895AB3FD8 |  Amostra FORA (25%)  |   133.0   |   80.0  |   27.0  |
# | 8BF40ABF3B6654BA90383F0DBA1EECBF |  Amostra FORA (25%)  |   270.0   |  170.0  |   52.0  |
# | E64426F3A40389A804CD27AE3FD09035 |  Amostra FORA (25%)  |   220.0   |  147.0  |   26.0  |
# | 7BC601856DC6EF294FA513F290D010C2 |  Amostra FORA (25%)  |   204.0   |  112.0  |   64.0  |
# | 3918C12A3DCE6E4FF4616D2627AFA29A |  Amostra FORA (25%)  |   207.0   |  134.0  |   44.0  |
# | AE666C1E2460245F02903D511EFA512B |  Amostra FORA (25%)  |   234.0   |  154.0  |   57.0  |
# | 0B743EBDDEBC79095EE97C4FB18A4F37 |  Amostra FORA (25%)  |   223.0   |  157.0  |   43.0  |
# | 8BBE206A383A19457E9445407FD21D2F |  Amostra FORA (25%)  |   215.0   |  141.0  |   46.0  |
# | 6ECBE18591DF3B985D50F890DFE1C7F0 |  Amostra FORA (25%)  |   168.0   |  110.0  |   35.0  |
# | 5EE74EEDDB3C6F5C7151B70602418409 |  Amostra FORA (25%)  |   136.0   |   78.0  |   35.0  |
# | 8326E424EC17B24CBBAA6CA9B4073FB9 |  Amostra FORA (25%)  |   210.0   |  139.0  |   40.0  |
# | 1EB95A07E461446E8599A81DE9E9F725 |  Amostra FORA (25%)  |   280.0   |  205.0  |   55.0  |
# | EF7DCB642A7ADA943D06584C807F9F72 |  Amostra FORA (25%)  |   266.0   |  180.0  |   46.0  |
# | 3B550366687F0856D19D222810C44C02 |  Amostra FORA (25%)  |   213.0   |  145.0  |   52.0  |
# | B5256893F38160AB039EF6F5C8EA3016 |  Amostra FORA (25%)  |   293.0   |  206.0  |   69.0  |
# | 9FA29741DAFD459ABE40EEE3074B6CAE |  Amostra FORA (25%)  |   144.0   |   77.0  |   38.0  |
# | 55A6DAD402A9565F546390F2152DD647 |  Amostra FORA (25%)  |   235.0   |  161.0  |   53.0  |
# | C656DFCBEBEB9A807DB3AABF32827352 |  Amostra FORA (25%)  |   215.0   |  136.0  |   50.0  |
# | 7126FC3682694D287618B68C7DCEFB4A |  Amostra FORA (25%)  |   203.0   |  123.0  |   65.0  |
# | 6A40C2A7AB6BDF7765A1B28D2F7F149C |  Amostra FORA (25%)  |   199.0   |  115.0  |   67.0  |
# | 2CF13C11FFF4416B635DF3E75A271814 |  Amostra FORA (25%)  |   194.0   |  126.0  |   53.0  |
# | 58F8ACAD27A01913B9D10C7451ED67DC |  Amostra FORA (25%)  |   198.0   |   77.0  |   30.0  |
# | C70A0CB57B2136FF6110FB7C39445010 |  Amostra FORA (25%)  |   201.0   |  124.0  |   50.0  |
# | 26E9CFB8E5F2346A5FC52155C7A1263B |  Amostra FORA (25%)  |   219.0   |  118.0  |   86.0  |
# | 10652A862132F8E1C917C425BC9D8F1E |  Amostra FORA (25%)  |   242.0   |  163.0  |   50.0  |
# | ED02382A597C42CC476D0EE6D64C9C01 |  Amostra FORA (25%)  |   100.0   |   38.0  |   35.0  |
# | 6AB557A729DF5AF937268C4AE9E6BBF7 |  Amostra FORA (25%)  |   218.0   |  138.0  |   62.0  |
# | EB5CFF33BF4F9CC2F9D8CCBF4D44C2F5 |  Amostra FORA (25%)  |   207.0   |  141.0  |   35.0  |
# | D089A558A0C354582147F9811D4AC671 |  Amostra FORA (25%)  |   220.0   |  123.0  |   66.0  |
# | 4B944C8A29620042866167F115E8235C |  Amostra FORA (25%)  |   194.0   |  117.0  |   46.0  |
# | A0DB05DC4113AEA746E915410F03A6BB |  Amostra FORA (25%)  |   207.0   |  134.0  |   45.0  |
# | 86205AF20B74A42FD80CA42EAE3BD46E |  Amostra FORA (25%)  |   168.0   |  107.0  |   33.0  |
# | A6BF94EADFEAB4BD8F6A015A7FDBB6E3 |  Amostra FORA (25%)  |   229.0   |  139.0  |   63.0  |
# | 7CFD00128AB55BCCDDA9EF0E2D5B211B |  Amostra FORA (25%)  |   185.0   |  124.0  |   38.0  |
# | 9A139F916F322D06C3ED79F7948EB4E9 |  Amostra FORA (25%)  |   110.0   |   60.0  |   25.0  |
# | 2589E7ECB7A74B4832AE66A060BDEFBE |  Amostra FORA (25%)  |   254.0   |  154.0  |   58.0  |
# | 0AADE1EE15EE8EF3A066D9DCA985069B |  Amostra FORA (25%)  |   209.0   |  124.0  |   70.0  |
# | 7E688DC08B777B2D6F313EF945B0D17D |  Amostra FORA (25%)  |   197.0   |  124.0  |   33.0  |
# | 049845D55B60E812AD5DC2F3C72D7B91 |  Amostra FORA (25%)  |   129.0   |   83.0  |   30.0  |
# | CDF835943C11252178FE5D03C3A6030F |  Amostra FORA (25%)  |   216.0   |  108.0  |   69.0  |
# | 0C39705D250C4005AD05094D01A650B0 |  Amostra FORA (25%)  |   208.0   |   93.0  |  100.0  |
# | C68871DBA0E8543EBE9CDBB309598A86 |  Amostra FORA (25%)  |   214.0   |  140.0  |   38.0  |
# | 05520AFACAEA6D5A102FF533BA7E219E |  Amostra FORA (25%)  |   241.0   |  169.0  |   47.0  |
# | ADB3FFE072FCE1B4A0D56AA040FF9659 |  Amostra FORA (25%)  |   164.0   |   91.0  |   36.0  |
# | B5CE4CD89C22B43E40F379971B0BEFF7 |  Amostra FORA (25%)  |   199.0   |  127.0  |   48.0  |
# | 1D89970597C0D67BF1CCFC9BEE11EB84 |  Amostra FORA (25%)  |    98.0   |   38.0  |   29.0  |
# | 00D692EAD1F6850500D4F06541E9AC1D |  Amostra FORA (25%)  |   105.0   |   57.0  |   25.0  |
# | 4CAF0DB54CADEC5E8E445E6305775854 |  Amostra FORA (25%)  |    85.0   |   30.0  |   38.0  |
# | 18FF22A391C426278FC87FCAEF368EED |  Amostra FORA (25%)  |   160.0   |  105.0  |   33.0  |
# | DFC0B850EA3B81BD2960CA9978B93541 |  Amostra FORA (25%)  |   168.0   |  109.0  |   35.0  |
# | 9FAF0BD4948F2D1C3D2DF369FF7811F3 |  Amostra FORA (25%)  |   107.0   |   51.0  |   37.0  |
# | 5ECA0813307EA4454D66CE1AE217EEEB |  Amostra FORA (25%)  |   219.0   |  130.0  |   58.0  |
# | A6534CD6D22CDC7BCE2E0721D2E594A0 |  Amostra FORA (25%)  |   187.0   |  139.0  |   32.0  |
# | 59B5EED612E75F80FE79E453A92472FC |  Amostra FORA (25%)  |   201.0   |  132.0  |   48.0  |
# | 91F7A6D4741BB4DE782B84E7718CBA2B |  Amostra FORA (25%)  |   178.0   |  111.0  |   32.0  |
# | 6F002419278D4101CD24095320FAB3E7 |  Amostra FORA (25%)  |   205.0   |  129.0  |   55.0  |
# | 44148D9E89F5A5F419FEC577A25FD2EC |  Amostra FORA (25%)  |   202.0   |  126.0  |   56.0  |
# | 8FF704CAA8CFF106F52A8EA58B328A71 |  Amostra FORA (25%)  |   120.0   |   56.0  |   37.0  |
# | AFE8682538ECFB38A92B4F514E0E366A |  Amostra FORA (25%)  |   194.0   |  127.0  |   33.0  |
# | A38C93809B7E115433EF490084FA35AA |  Amostra FORA (25%)  |   274.0   |  213.0  |   37.0  |
# | 5A63F1DC09073AF469E2A4B0A02B341E |  Amostra FORA (25%)  |   116.0   |   61.0  |   35.0  |
# | B18F3758414B51DFFF9B2925085CCBC7 |  Amostra FORA (25%)  |   252.0   |  185.0  |   49.0  |
# | 916C6A334FC9C25381FEF8AF44FFD06F |  Amostra FORA (25%)  |   144.0   |   91.0  |   37.0  |
# | B1BE2EF457A8B66DA55F26F87A1519AD |  Amostra FORA (25%)  |   196.0   |  119.0  |   62.0  |
# | 9A49C8322D17AA62B87CD0B12BB64A11 |  Amostra FORA (25%)  |   212.0   |  136.0  |   60.0  |
# | 99C066474E5C85EA8B5CF4C432876460 |  Amostra FORA (25%)  |   132.0   |   74.0  |   35.0  |
# | C413C178A4B805EC9DEB2621516794A1 |  Amostra FORA (25%)  |   110.0   |   52.0  |   37.0  |
# | E4FEECFF2FF0D891EE8EFAF1EFC05192 |  Amostra FORA (25%)  |   151.0   |   96.0  |   33.0  |
# | 973B3C0C342F3B83660EB262D5008BA2 |  Amostra FORA (25%)  |   193.0   |  122.0  |   56.0  |
# | E6BFEF25F8979D92A419897AC9F3FC27 |  Amostra FORA (25%)  |   134.0   |   78.0  |   33.0  |
# | C5B9680128053E43BB07ED2953979ECD |  Amostra FORA (25%)  |   254.0   |  172.0  |   61.0  |
# | C06A5A02D7E78E7782467406F395555A |  Amostra FORA (25%)  |   122.0   |   69.0  |   26.0  |
# | D5AD8E1D74692AC56498846CC199168D |  Amostra FORA (25%)  |   274.0   |  194.0  |   47.0  |
# | C917EA391723C3E959649C29B99D7C4F |  Amostra FORA (25%)  |   217.0   |  141.0  |   54.0  |
# | 90EB61654F4A7252F982FBC92B31096C |  Amostra FORA (25%)  |   196.0   |  121.0  |   47.0  |
# | ABAE678DE2AF2F578A3E7B54A178C5DF |  Amostra FORA (25%)  |   326.0   |  234.0  |   71.0  |
# | FE5FDBAD4ECA2516B178DB0D61B61707 |  Amostra FORA (25%)  |   167.0   |  116.0  |   32.0  |
# | EDE2D4D5A7FCC6ED23F7A60708ADCA5C |  Amostra FORA (25%)  |   213.0   |  122.0  |   69.0  |
# | AFA60D93F9FF1E4F7E3F9D6C0AA7D83A |  Amostra FORA (25%)  |   258.0   |  173.0  |   47.0  |
# | 3020B66A59F572762CE324EF7834F9FC |  Amostra FORA (25%)  |   212.0   |  142.0  |   39.0  |
# | 21CDB1A01A173A410BD00C5B2B4B4E84 |  Amostra FORA (25%)  |   212.0   |  151.0  |   35.0  |
# | 34A9ACF616F0BD2D3C2E164F580F1E09 |  Amostra FORA (25%)  |   201.0   |  115.0  |   37.0  |
# | 47890FEC90AA058D8A008C558BAC3B20 |  Amostra FORA (25%)  |   286.0   |  174.0  |   84.0  |
# | D767D36109676759A0EBAC1203F18392 |  Amostra FORA (25%)  |   223.0   |  123.0  |   85.0  |
# | E1C4C53F72560AF5A60EA5C8741A40D8 |  Amostra FORA (25%)  |   206.0   |  122.0  |   46.0  |
# | 07572571692BF322850D58923E3DE917 |  Amostra FORA (25%)  |   193.0   |  120.0  |   47.0  |
# | 353D9E4B4732F9802124C3090ED4B601 |  Amostra FORA (25%)  |   217.0   |  140.0  |   56.0  |
# | 2FA7FCFD95786F3CEB873B89E302897E |  Amostra FORA (25%)  |   209.0   |  123.0  |   34.0  |
# | 89FBE24994408F50D71AAC599A9CF576 |  Amostra FORA (25%)  |   191.0   |   87.0  |   90.0  |
# | 54459AF985E05868FD7A7FFF69FD5BBF |  Amostra FORA (25%)  |   159.0   |   96.0  |   32.0  |
# | AF185B2BA692930490F3F3E6B12876EF |  Amostra FORA (25%)  |   203.0   |  117.0  |   68.0  |
# | 9D711F7C30E6FE9CF83DDB24135AB8CD |  Amostra FORA (25%)  |   194.0   |  131.0  |   33.0  |
# | E37E9F5E44B9333B88BD7065B085D631 |  Amostra FORA (25%)  |   226.0   |  119.0  |   90.0  |
# | 4AE4D8E5F5926EEB56D745DB7848CB1C |  Amostra FORA (25%)  |   115.0   |   63.0  |   36.0  |
# | 572B1DF71B0AEDF2222E2A6372F2F953 |  Amostra FORA (25%)  |   177.0   |  105.0  |   42.0  |
# | 77DA0E0BFEC7D71AEEC0C498AE3929A3 |  Amostra FORA (25%)  |   211.0   |  135.0  |   61.0  |
# | 9AA14A8358A61F33D98F214DDA2081DC |  Amostra FORA (25%)  |   235.0   |  163.0  |   46.0  |
# | C0592A1E70387B04B9E4DD3D11F88A26 |  Amostra FORA (25%)  |   244.0   |  167.0  |   50.0  |
# | 63287E9C92CF98A5375E4225C3659838 |  Amostra FORA (25%)  |   209.0   |  118.0  |   74.0  |
# | CB9A4F92D07A719EE647A5530D5D7A40 |  Amostra FORA (25%)  |   165.0   |  111.0  |   39.0  |
# | 377076EDB39737F0DF6AB2CA02A92BBB |  Amostra FORA (25%)  |   116.0   |   63.0  |   37.0  |
# | BDAF416A13A6128C213905BB7845D01D |  Amostra FORA (25%)  |   211.0   |  139.0  |   45.0  |
# | DA17370FE995D01C791FEFAEB5AD6E18 |  Amostra FORA (25%)  |   127.0   |   67.0  |   38.0  |
# | 0CFA15E32130B847E15A2503C5141A63 |  Amostra FORA (25%)  |   246.0   |  155.0  |   65.0  |
# | 200642030636DB113B7299CAA20520B6 |  Amostra FORA (25%)  |   198.0   |  104.0  |   80.0  |
# | 1A166C06B9604E5309C6F50620B22079 |  Amostra FORA (25%)  |   136.0   |   79.0  |   39.0  |
# | 36DD9CAA1A038F616F4539FAEB2624BE |  Amostra FORA (25%)  |   190.0   |  132.0  |   35.0  |
# | EA4644FF57216196B46F61D133932C65 |  Amostra FORA (25%)  |   101.0   |   56.0  |   31.0  |
# | B5B0E3FF44FE2801426AB139A7327411 |  Amostra FORA (25%)  |   139.0   |   84.0  |   38.0  |
# | F42FFF23D10308A8D4E21AB4C7D2AE5B |  Amostra FORA (25%)  |   152.0   |   92.0  |   34.0  |
# | 03AD4A3C6B5286A74D25F567717797C1 |  Amostra FORA (25%)  |   211.0   |  133.0  |   57.0  |
# | 4CFF0978C91A2EC55F1894C39FC09F77 |  Amostra FORA (25%)  |   195.0   |  117.0  |   58.0  |
# | 9B6A4B46B9E24E36BD04C1E7F7481A47 |  Amostra FORA (25%)  |   142.0   |   86.0  |   32.0  |
# | 880E93C84E588455360861926EF9196B |  Amostra FORA (25%)  |   229.0   |  154.0  |   56.0  |
# | B9406216A39793D26A882A967DA7017B |  Amostra FORA (25%)  |   212.0   |  131.0  |   64.0  |
# | D9E00D7B2C3D1AD17FEDCB29D989FDFC |  Amostra FORA (25%)  |   108.0   |   53.0  |   37.0  |
# | 43FB46DD4E2E7A5BF3E661F50E69F678 |  Amostra FORA (25%)  |   155.0   |   96.0  |   38.0  |
# | 06686D6F46EA1F44C82751D073466A70 |  Amostra FORA (25%)  |    83.0   |   24.0  |   32.0  |
# | 7E649A61B4A743DF37F435411194DF71 |  Amostra FORA (25%)  |    76.0   |   20.0  |   35.0  |
# | 956FED9ADDE7D46D9A9287666EF367FD |  Amostra FORA (25%)  |   202.0   |  128.0  |   52.0  |
# | 0713B2E1DD0EA2D9A128C322493BC03C |  Amostra FORA (25%)  |   199.0   |  125.0  |   35.0  |
# | 128FAAFBBF2F119B27578A4B78079EB7 |  Amostra FORA (25%)  |   214.0   |  131.0  |   61.0  |
# | A0B353BFF762C25B6ABA7D54B019293E |  Amostra FORA (25%)  |   234.0   |  142.0  |   65.0  |
# | 61B10CE8E7610F2832568B73C1E0D39D |  Amostra FORA (25%)  |   192.0   |  111.0  |   48.0  |
# | 7E9F05E6AC2E8C1950F2B39B631D8ABB |  Amostra FORA (25%)  |   123.0   |   None  |   38.0  |
# | C098214B5EC7F1D4CC9548B22AAB790E |  Amostra FORA (25%)  |   192.0   |  122.0  |   42.0  |
# | 2F2C731F3D7FB250FDD7A30EA52804DD |  Amostra FORA (25%)  |   209.0   |  124.0  |   69.0  |
# | 8907527273FA3134A8DE09EBEC130BD2 |  Amostra FORA (25%)  |   218.0   |  154.0  |   43.0  |
# | D6D9AFFF7AAD17F4629CB9455A7A0E2C |  Amostra FORA (25%)  |   162.0   |  110.0  |   39.0  |
# | 949AFC96F7852049F31D8FCEE3EDEE6A |  Amostra FORA (25%)  |    86.0   |   33.0  |   39.0  |
# | E33918712ABD51E94C7B63C77E1E4AAE |  Amostra FORA (25%)  |   135.0   |   73.0  |   38.0  |
# | C063124E374F03D601B326E18DD8F624 |  Amostra FORA (25%)  |   204.0   |  127.0  |   61.0  |
# | FC4790DCEDC849192248971C90EF5F6B |  Amostra FORA (25%)  |   204.0   |  137.0  |   46.0  |
# | 6649C6994773D6D05C45D737DA88DF94 |  Amostra FORA (25%)  |   215.0   |  136.0  |   59.0  |
# | DF18C3A654F38FAADBC79E06C5AB0864 |  Amostra FORA (25%)  |   193.0   |  108.0  |   73.0  |
# | 22297B9D3D84EA5BDFA9E36305BCD56E |  Amostra FORA (25%)  |   197.0   |  118.0  |   43.0  |
# | 355B012D5DDE3B1827E50E5D184BD2D0 |  Amostra FORA (25%)  |   194.0   |  104.0  |   77.0  |
# | 5F5A11ABC75FA865357C5EC369E1C153 |  Amostra FORA (25%)  |   201.0   |  139.0  |   34.0  |
# | 1DC742690D0240DE2882EE0463F0E42A |  Amostra FORA (25%)  |   182.0   |  121.0  |   32.0  |
# | B14F9DA97755A6ABFECFDF85A4CC1A4E |  Amostra FORA (25%)  |   207.0   |  134.0  |   55.0  |
# | B1B94AE44BC5D30E92B1DF4AB611764C |  Amostra FORA (25%)  |   154.0   |   85.0  |   32.0  |
# | F778A9AE75E2197189489F46E0E696C6 |  Amostra FORA (25%)  |   209.0   |  113.0  |   66.0  |
# | 1173EE21A7D1C31611CF3757702522D3 |  Amostra FORA (25%)  |   203.0   |  132.0  |   32.0  |
# | 17E426B5080A24ABF48A321A327DCDE2 |  Amostra FORA (25%)  |   216.0   |  141.0  |   52.0  |
# | 210282511CAB15AB46C9BA72D4C3DDEE |  Amostra FORA (25%)  |   205.0   |  106.0  |   85.0  |
# | F39942707DEBEFFDCF99F329DFFAA5D3 |  Amostra FORA (25%)  |   232.0   |  165.0  |   49.0  |
# | 4EDB741B024A9D54F51967C34B359BDF |  Amostra FORA (25%)  |   152.0   |   91.0  |   34.0  |
# | 1C8D0112A7687F590A28F63A862335FB |  Amostra FORA (25%)  |   127.0   |   72.0  |   28.0  |
# | 1F6ADA518E2DCEE0BC74C75435326253 |  Amostra FORA (25%)  |   190.0   |  101.0  |   71.0  |
# | A90F7D1D6AA0C1106764403847944DAB |  Amostra FORA (25%)  |   200.0   |  126.0  |   55.0  |
# | D0F4CE81101D903CC17A3DDB1B65CE9B |  Amostra FORA (25%)  |   263.0   |  164.0  |   71.0  |
# | FC20D4C2A193C47C9E70E2BDA6F75AFF |  Amostra FORA (25%)  |   227.0   |  159.0  |   48.0  |
# | DA09854E466CD7DE8F35126B9CEC6ED7 |  Amostra FORA (25%)  |    87.0   |   39.0  |   30.0  |
# | 0FE051A0CE3BFCD32CAA7F7E6C383743 |  Amostra FORA (25%)  |   207.0   |  130.0  |   54.0  |
# | A0F31452BF0A61B335C415943ACA601B |  Amostra FORA (25%)  |   202.0   |  139.0  |   47.0  |
# | 4A94553B6D31668A7CCBBC712B41B687 |  Amostra FORA (25%)  |   230.0   |  122.0  |   81.0  |
# | 71199FA446CF588084361DA19858D64F |  Amostra FORA (25%)  |   190.0   |   92.0  |   67.0  |
# | B07E6BCA1EF0F87ADA60CFCF53D13B18 |  Amostra FORA (25%)  |   135.0   |   77.0  |   33.0  |
# | 26818F540E92D13677F7632ED468ABAA |  Amostra FORA (25%)  |   127.0   |   85.0  |   33.0  |
# | 555DE62FC2AF79222548812A181BC5E2 |  Amostra FORA (25%)  |   235.0   |  155.0  |   54.0  |
# | 2CD19E9267C7123195C22164DB6D0B41 |  Amostra FORA (25%)  |   135.0   |   77.0  |   36.0  |
# | 05F409D4C0E1753C497666F42F8EE4C7 |  Amostra FORA (25%)  |   192.0   |  122.0  |   47.0  |
# | CBD40482F549B2F99C823C7111F5B4A1 |  Amostra FORA (25%)  |   146.0   |   89.0  |   38.0  |
# | 806BBD561AD8264D6278BD31EC24609C |  Amostra FORA (25%)  |   152.0   |   89.0  |   31.0  |
# | 4301CF7F176A978FA91EB9151CC7CF0E |  Amostra FORA (25%)  |   237.0   |  176.0  |   32.0  |
# | 0C7BA93E4789FAA5864E5A4C54F29D8C |  Amostra FORA (25%)  |   205.0   |  126.0  |   59.0  |
# | E56CAA14DF55BC6F0A842225D5A05A60 |  Amostra FORA (25%)  |   211.0   |  126.0  |   70.0  |
# | 815FB26B79B620C7918E73F76CB6E2F2 |  Amostra FORA (25%)  |   216.0   |  143.0  |   51.0  |
# | 9B5E45EA8EEBC943DE46E18242FE688D |  Amostra FORA (25%)  |   197.0   |   91.0  |   69.0  |
# | 7DE63E53F100C37013195B36B7EBA10A |  Amostra FORA (25%)  |   220.0   |  151.0  |   56.0  |
# | E59C008EA0C737E8DC0E30A01E32F9BB |  Amostra FORA (25%)  |   223.0   |  148.0  |   60.0  |
# | EEDDE25268E705A26735B8BDBD3460CB |  Amostra FORA (25%)  |    92.0   |   43.0  |   33.0  |
# | 47594438708C883E3A43678C4EB77D64 |  Amostra FORA (25%)  |   199.0   |  126.0  |   53.0  |
# | 9B97E1EEBF2BC3E059A9DD30934DD98F |  Amostra FORA (25%)  |   251.0   |  174.0  |   33.0  |
# | 829DF61400D641E0EC3B3E7472F79F66 |  Amostra FORA (25%)  |   203.0   |  138.0  |   37.0  |
# | 0CC86B8A9973FCF099A765EA6270B58B |  Amostra FORA (25%)  |   195.0   |  147.0  |   32.0  |
# | 33A2D50D1B6C0021FA679C445D226622 |  Amostra FORA (25%)  |   281.0   |  180.0  |   57.0  |
# | 42CE73A5464F4B8054EA554D2BD675E9 |  Amostra FORA (25%)  |   192.0   |  104.0  |   64.0  |
# | 6361F36C7DE9D0954AA740741D6CD9B4 |  Amostra FORA (25%)  |   199.0   |  121.0  |   40.0  |
# | 8E47F53158EC7D07A0A933C0C25DC6F8 |  Amostra FORA (25%)  |   190.0   |   97.0  |   71.0  |
# | 74D0DC3D439041BDE6730FF5438E3B2B |  Amostra FORA (25%)  |   204.0   |  138.0  |   37.0  |
# | B47EB9C0303C563F5D25DB20F9355DB6 |  Amostra FORA (25%)  |   198.0   |  130.0  |   46.0  |
# | EB0CFE42E4F4D7464AD549DF75610BF3 |  Amostra FORA (25%)  |   161.0   |   None  |   34.0  |
# | BFE32CA9F872596304090899612CC87A |  Amostra FORA (25%)  |   200.0   |  133.0  |   50.0  |
# | 6F032F97265CED09AB6E5C26A25293EE |  Amostra FORA (25%)  |   235.0   |  139.0  |   70.0  |
# | 56F933A6B23DFFAC3167F51638A22E1D |  Amostra FORA (25%)  |   228.0   |  124.0  |   89.0  |
# | B79922B115FE1C87308A3DE749A07853 |  Amostra FORA (25%)  |   205.0   |  130.0  |   50.0  |
# | 5BAD77CF6CABA45DCFBFF19E9DC1BFEA |  Amostra FORA (25%)  |   191.0   |  117.0  |   45.0  |
# | 2139841F99ABC2A223F37F7D7ABCF585 |  Amostra FORA (25%)  |   157.0   |  104.0  |   37.0  |
# | 63A72A3447C2C02F0EFD72674BA7FA47 |  Amostra FORA (25%)  |   203.0   |  110.0  |   77.0  |
# | F09A54BA413A932BEFD9846DACEA76AC |  Amostra FORA (25%)  |   203.0   |  103.0  |   79.0  |
# | 024CD5250A48A14761C5A4D167C54235 |  Amostra FORA (25%)  |   174.0   |  113.0  |   39.0  |
# | CF4C65BF010813214F3AE34DBD400E50 |  Amostra FORA (25%)  |   181.0   |  107.0  |   35.0  |
# | 4B241A5FAE453DF5DDB14ADE402E8FE8 |  Amostra FORA (25%)  |   175.0   |  100.0  |   32.0  |
# | E063A4A7247475420F28DE00BB3372FA |  Amostra FORA (25%)  |   203.0   |  122.0  |   68.0  |
# | C0BE457B954FFB8E92B2CC760546DA89 |  Amostra FORA (25%)  |   196.0   |  106.0  |   65.0  |
# | 022E26F4A6FCAB15894DF9A2524BAC7C |  Amostra FORA (25%)  |   218.0   |  125.0  |   66.0  |
# | 7540874F7311979C63DBA24D2AC87D61 |  Amostra FORA (25%)  |   155.0   |   95.0  |   37.0  |
# | F08457118C2239C7A466BE60C07E1A62 |  Amostra FORA (25%)  |   206.0   |  147.0  |   40.0  |
# | 96747C4D2E1EE9BDB5FE9409F7B5D3A6 |  Amostra FORA (25%)  |   230.0   |  140.0  |   68.0  |
# | 6BC83115E18D98BBBF9CE6AC542E9F4E |  Amostra FORA (25%)  |   188.0   |  123.0  |   35.0  |
# | 49D4B8302A32830F8144C11EBAD2CC23 |  Amostra FORA (25%)  |   178.0   |  115.0  |   29.0  |
# | A0A9C986C47FA4ACC52F7E1D9865E4A5 |  Amostra FORA (25%)  |   291.0   |  176.0  |   99.0  |
# | 7B2E7FD841C91F18CFD4A0DF06F6DF5D |  Amostra FORA (25%)  |    91.0   |   39.0  |   38.0  |
# | 2535622479C496128E99AD47C488F516 |  Amostra FORA (25%)  |   140.0   |   85.0  |   38.0  |
# | 787F43F87BF53607D613E7A12D8CD2E7 |  Amostra FORA (25%)  |   251.0   |  169.0  |   53.0  |
# | B4D843C61E316A2C3AD7948DF0A9DFA1 |  Amostra FORA (25%)  |   125.0   |   77.0  |   34.0  |
# | 8947AC2C5A0CB9A09CCB790AE4E80AFB |  Amostra FORA (25%)  |   197.0   |  125.0  |   58.0  |
# | 078A5E0A615ED91DA3313A30C73B3879 |  Amostra FORA (25%)  |   310.0   |  212.0  |   54.0  |
# | 74B0412DFF1AF991F0FF6334B32046F5 |  Amostra FORA (25%)  |   188.0   |  121.0  |   34.0  |
# | 326463CC609AD10A9C38582E2D5793F5 |  Amostra FORA (25%)  |   127.0   |   68.0  |   35.0  |
# | 693850555F61D8A81D3ECD0C24F57BB1 |  Amostra FORA (25%)  |   206.0   |  115.0  |   68.0  |
# | 7B96B7D963509C3EEDD31700848A77F2 |  Amostra FORA (25%)  |   156.0   |  102.0  |   31.0  |
# | 4F60D50FBDFF8056D010071E38BC283A |  Amostra FORA (25%)  |   165.0   |  107.0  |   38.0  |
# | 4BD4B5D5DDB1E9E9912A1D450C5D36DE |  Amostra FORA (25%)  |   226.0   |  144.0  |   64.0  |
# | F9F47ECA9E0D65B6E1C8488ACAD3AB81 |  Amostra FORA (25%)  |   158.0   |  101.0  |   38.0  |
# | 9CC844CCBC70D17D89571394ECD26393 |  Amostra FORA (25%)  |   206.0   |  127.0  |   61.0  |
# | 8EF5C8CFD56F5C7C29BA4AD08C4B0F7D |  Amostra FORA (25%)  |   173.0   |  103.0  |   39.0  |
# | 2F1F1579D89BD9E07DBF236668CF82F5 |  Amostra FORA (25%)  |   192.0   |  133.0  |   43.0  |
# | B2C48F1E7CFF7E8DEFED07FE5777D510 |  Amostra FORA (25%)  |   265.0   |  204.0  |   33.0  |
# | 2DCAD8209CCFBC66F15F9FB858E8FDEF |  Amostra FORA (25%)  |   166.0   |   89.0  |   33.0  |
# | 5E215D0C8FA7F37439497FC42E812313 |  Amostra FORA (25%)  |   125.0   |   78.0  |   27.0  |
# | 55023BEDF08EB02E1D30DEB5EC4962D4 |  Amostra FORA (25%)  |   142.0   |   83.0  |   36.0  |
# | 532937570B68DE1191332175E643ABDB |  Amostra FORA (25%)  |   198.0   |  133.0  |   37.0  |
# | B762CF7284A85ABD34E0FE68041209EF |  Amostra FORA (25%)  |   209.0   |  138.0  |   33.0  |
# | 5BE87AE170CBB6752CA41463C9A1380F |  Amostra FORA (25%)  |   154.0   |   90.0  |   36.0  |
# | 9C5CFBECCDB3F159C8AFC2C41A10D670 |  Amostra FORA (25%)  |   197.0   |  116.0  |   49.0  |
# | 49EAC8DE02D4444683AABC04AE119E88 |  Amostra FORA (25%)  |   200.0   |  110.0  |   75.0  |
# | ADF749CFB2377E6979C95129D1BEAD0D |  Amostra FORA (25%)  |   258.0   |  146.0  |   91.0  |
# | F3F4A192CD0E5504F26CCB2DAA109A2A |  Amostra FORA (25%)  |   239.0   |  156.0  |   36.0  |
# | 54A84DF4A6E1EED47649C3A045B8E3E3 |  Amostra FORA (25%)  |   171.0   |  108.0  |   38.0  |
# | 5974EB682E8A6F50FA45579269B098B8 |  Amostra FORA (25%)  |   192.0   |  124.0  |   48.0  |
# | 4C71D11B74D9FD051C09DE7D2E443C19 |  Amostra FORA (25%)  |   204.0   |  130.0  |   54.0  |
# | EB6D23117CA0C2C75AF4D700CA00EC06 |  Amostra FORA (25%)  |   179.0   |  122.0  |   36.0  |
# | CBB9FD03131BE49E992BCCE12FFD23C8 |  Amostra FORA (25%)  |   107.0   |   53.0  |   38.0  |
# | E11BCC97B65345DA5E00ABF1CAD1A0B0 |  Amostra FORA (25%)  |   221.0   |  138.0  |   43.0  |
# | 5F1F7BA1C854EE92B2A628B93DBCB8A4 |  Amostra FORA (25%)  |   150.0   |   80.0  |   39.0  |
# | 7413610B00EF69FE333E17DB1A42CD00 |  Amostra FORA (25%)  |   187.0   |  126.0  |   31.0  |
# | 35A64C0111D349D5B81D7E8D35564DA1 |  Amostra FORA (25%)  |   180.0   |  117.0  |   37.0  |
# | B96464390D7C1684BF8BF74066BBCC2C |  Amostra FORA (25%)  |   142.0   |   85.0  |   37.0  |
# | AEE10D1D2962EC2B7F7F9CD2AA5E76EE |  Amostra FORA (25%)  |    97.0   |   41.0  |   34.0  |
# | 27C16D7432C72CDB75A93D55C8CA744B |  Amostra FORA (25%)  |   196.0   |  125.0  |   49.0  |
# | 3DB36A8BAEA00C830EF905E4DFE60AA6 |  Amostra FORA (25%)  |   215.0   |  128.0  |   48.0  |
# | 135CC0C5FB8959B43B23D158B18B4085 |  Amostra FORA (25%)  |   192.0   |  128.0  |   50.0  |
# | C9FCE73CA0E549E35074B9DE78AFC823 |  Amostra FORA (25%)  |   262.0   |  175.0  |   43.0  |
# | 708394965AE1BAB8A395E513BA601F39 |  Amostra FORA (25%)  |   191.0   |  102.0  |   67.0  |
# | EA9577D3780796593BA4F677CA435B74 |  Amostra FORA (25%)  |   248.0   |  183.0  |   47.0  |
# | 876238A89F889438323D27689545A79B |  Amostra FORA (25%)  |   198.0   |  108.0  |   53.0  |
# | D6BA6A253E1A00143C7BF0206C3D643F |  Amostra FORA (25%)  |   163.0   |  105.0  |   34.0  |
# | EB3BCE42BA52F720ACD6BA909DA2756F |  Amostra FORA (25%)  |   217.0   |  138.0  |   47.0  |
# | 4384DF9F1DFFBFDA03C189CE9AAAE7E8 |  Amostra FORA (25%)  |   180.0   |  134.0  |   29.0  |
# | DF52AB7806B198A4C9510A45241DEB4D |  Amostra FORA (25%)  |   233.0   |  136.0  |   81.0  |
# | F5DCE4C1977A3199CB631AA75F2BF934 |  Amostra FORA (25%)  |   197.0   |  142.0  |   40.0  |
# | 356C651B88635B609CB603F554A8AC2D |  Amostra FORA (25%)  |   192.0   |  103.0  |   72.0  |
# | DC0352F78EEBBA5A43E42A082BA2B928 |  Amostra FORA (25%)  |   235.0   |  156.0  |   63.0  |
# | AFEFB6B18DD7D7C50B2E056D737B9B05 |  Amostra FORA (25%)  |   158.0   |   95.0  |   36.0  |
# | E5AD13B4875AB1E40375C209B851AC97 |  Amostra FORA (25%)  |   154.0   |   99.0  |   36.0  |
# | 9D5580A12AEE5976730D6F70CE1D8E8A |  Amostra FORA (25%)  |   157.0   |  103.0  |   37.0  |
# | 860F623ADB28CCD8ED2BC9852C278613 |  Amostra FORA (25%)  |   138.0   |   84.0  |   27.0  |
# | 7CD8F70BD23C6E9AF674CE0AC9A06E4A |  Amostra FORA (25%)  |   176.0   |  120.0  |   34.0  |
# | B8BE44CE14DB95FBA7F068264BA93DDE |  Amostra FORA (25%)  |   210.0   |  145.0  |   43.0  |
# | 358F106C62268DC57983735040ECCC30 |  Amostra FORA (25%)  |   223.0   |  110.0  |   86.0  |
# | 356BB15D5CC1D5E86C6B33CF5124F02E |  Amostra FORA (25%)  |   214.0   |  135.0  |   58.0  |
# | 7AAE742CC2A773A68461B7530378C5D4 |  Amostra FORA (25%)  |   203.0   |  128.0  |   49.0  |
# | 1CA7C9C8011B37B0C209724DC77C24DB |  Amostra FORA (25%)  |   195.0   |  123.0  |   57.0  |
# | 810CBD8F59B204273D37E8D187E1AB6B |  Amostra FORA (25%)  |   216.0   |  113.0  |   81.0  |
# | DCAD88DD3E6C8E65E094729E85FE772C |  Amostra FORA (25%)  |   153.0   |   89.0  |   36.0  |
# | D974E707FBF2F59AF7827EF973FBCBE3 |  Amostra FORA (25%)  |   205.0   |  127.0  |   61.0  |
# +----------------------------------+----------------------+-----------+---------+---------+
